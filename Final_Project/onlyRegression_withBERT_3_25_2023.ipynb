# %% [markdown]
# <a href="https://colab.research.google.com/github/heesukjang/W266_NLP_With_DeepLearning/blob/main/Final_Project/onlyRegression_withBERT_3_25_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install New Libraries**

# %%
# !pip install nltk
# !pip install wordcloud
# !pip install transformers
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-23-cf7a124832e8> in <module>
# ----> 1 get_ipython().system('pip install nltk')
#       2 get_ipython().system('pip install wordcloud')
#       3 get_ipython().system('pip install transformers')
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      96       kwargs.update({'also_return_output': True})
#      97
# ---> 98     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      99
#     100     if pip_warn:
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     451   # is expected to call this function, thus adding one level of nesting to the
#     452   # stack.
# --> 453   result = _run_command(
#     454       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     455   )
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     165   locale_encoding = locale.getpreferredencoding()
#     166   if locale_encoding != _ENCODING:
# --> 167     raise NotImplementedError(
#     168         'A UTF-8 locale is required. Got {}'.format(locale_encoding)
#     169     )
#
# NotImplementedError: A UTF-8 locale is required. Got ANSI_X3.4-1968

# %% [markdown]
# # **Importing Libraries**

# %%
#NLP related libraries
import transformers
print(f'transformers version: {transformers.__version__}')
from transformers import logging as hf_logging
from transformers import BertTokenizer, TFBertModel
hf_logging.set_verbosity_error()
import nltk
from nltk.tokenize import sent_tokenize
import spacy      
from spacy import displacy
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from wordcloud import ImageColorGenerator
from sklearn.model_selection import train_test_split
nltk.download('punkt')

# Other required libraries
import os
import pandas as pd
import numpy as np
import re
import copy
import sys
import warnings
warnings.filterwarnings("ignore")

# Data visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Tensorflow libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.utils.layer_utils import count_params
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import mae
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.losses import binary_crossentropy
from keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.regularizers import l1
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD
from keras.models import load_model

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# transformers version: 4.27.3
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # **General Functions**

# %% [markdown]
# ## **Set Config Parameters**

# %%
def set_config_param(seed = 99):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.backend.clear_session()
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/Kaggle"
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_columns', None)
    
    
set_config_param(20230214)

# %% [markdown]
# ## **Count Plot**

# %%
def plot_count(df, labels):
  sns.set_style('whitegrid')
  plt.figure(figsize=(18,10))
  for idx, label in enumerate(labels):
      plt.subplot(2, 3, idx+1)
      sns.countplot(x = label, data = df)

# %% [markdown]
# ## **Adding Feature Columns**

# %%
def add_feature(df):

    # Cleaning up full_text : Removing tabl and carriage return characters
    df['full_text'] = df["full_text"].replace(re.compile(r'[\n\r\t]'), ' ', regex=True)

    # Adding word count, sentence count, total score and full text length
    df['word_count'] = df['full_text'].apply(lambda x: len(x.split()))
    df['sentence_count'] = df['full_text'].apply(lambda x: len(sent_tokenize(x)))
    df['total_score'] = df['cohesion'] + df_train['syntax'] + df['vocabulary'] + df['phraseology'] + df['grammar'] + df['conventions']
    df['full_text_len'] = df['full_text'].apply(lambda x: len(x))

    # Adding mean, median score per label and indicator column 
    # whether the label value is below or above mean or median value
    for label in label_cols:
        df[label + '_avg_score'] = np.mean(df[label])
        df[label + '_above_or_below_avg_flag'] = np.where(df[label] > np.mean(df[label]), 1, 0)  
        df[label + '_median_score'] = np.median(df[label])
        df[label + '_above_or_below_median_flag'] = np.where(df[label] > np.median(df[label]), 1, 0)  
        df[label + '_rounded_val'] = np.round(df[label])  
    
    return df

# %% [markdown]
# ## **Getting Unique Values for Each Label**

# %%
def get_unique_values_for_labels(df, col_list):
    print('Unique Values in Each Metric:\n==================================================')
    for col in col_list:
        print(f'{col}: {df[col].unique()}')

# %% [markdown]
# ## **Getting Value Counts for Each Label**

# %%
def get_value_counts_for_labels(df, col_list):
    print('Counts for Each Metric:\n==================================================')
    for col in col_list:
        print(f"Column: {col}")
        print(f'{df[col].value_counts().sort_values()}')
        print("*****")

# %% [markdown]
# ## **Getting Histogram for a Column**

# %%
def get_histogram_for_col(df, col_list, col_name):
    sns.set_style('whitegrid')
    plt.figure(figsize=(18,10))
    for idx, label in enumerate(col_list):
        plt.subplot(2, 3, idx+1)
        sns.histplot(x=col_name, hue = label, data = df)
        plt.xlabel('Word Count', fontsize=10)

# %% [markdown]
# ## **Getting Count Plot for Indicator Columns**

# %%
def get_count_plot_for_ind_col(df, search_string, col_list):
    fig, ax = plt.subplots(1, len(col_list), figsize=(50,10))
    for idx, label in enumerate(col_list):
        sns.countplot(x = df[label + search_string], ax = ax[idx])
        ax[idx].set_title(label)

# %% [markdown]
# ## **Getting Bar Plot for Each Label**

# %%
def get_barplot_for_each_label(df, col_list, search_string):
    avg_score_cols = [col + search_string for col in col_list]
    plt.figure(figsize=(8,5))
    ax = sns.barplot(x=col_list, y=np.array(df[avg_score_cols].drop_duplicates())[0], palette='rocket')
    plt.xlabel('Scoring Metric', fontsize=12)
    if search_string == '_avg_score':
        plt.ylabel('Average Score', fontsize=12)
        plt.title('Average Score in Each Metric', fontsize=16)
    elif search_string == '_median_score':
        plt.ylabel('Median Score', fontsize=12)
        plt.title('Median Score in Each Metric', fontsize=16)

# %% [markdown]
# ## **Label Processing**

# %%
def get_cat_label_cols(col_list):
    return ['cat_' + col for col in col_list]

# %%
def apply_label_map(df, label_map, col_list):
  for col in col_list:
      df[col + '_map'] = df[col].map(label_map)
  return df

# %%
def get_label_values(df, col_list):
    return [np.array(df[col]) for col in col_list]

# %%
def get_label_dict(df, col_list_1, col_list_2):
    return dict(zip(col_list_2, get_label_values(df, col_list_1)))

# %% [markdown]
# ## **Plot Loss and Accuracy**

# %%
def plot_loss_accuracy(history, col_list):
    fig, ax = plt.subplots(2, 6, figsize=(16, 6), sharex='col', sharey='row')
    fig.tight_layout(pad=5.0)
    for idx, col in enumerate(col_list):

        ax[0, idx].plot(history[col + '_loss'], lw=2, color='darkgoldenrod')
        ax[0, idx].plot(history['val_' + col + '_loss'], lw=2, color='indianred')
        #ax[0, idx].legend(loc='center left')
        ax[0, idx].legend(['Train', 'Validation'], fontsize=5)
        ax[0, idx].set_xlabel('Epochs', size=10)
        ax[0, idx].set_title('Loss: ' + col)

        ax[1, idx].plot(history[col + '_accuracy'], lw=2, color='darkgoldenrod')
        ax[1, idx].plot(history['val_' + col + '_accuracy'], lw=2, color='indianred')
        #ax[0, idx].legend(loc='center left')
        ax[1, idx].legend(['Train', 'Validation'], fontsize=5)
        ax[1, idx].set_xlabel('Epochs', size=10)
        ax[1, idx].set_title('Accuracy: ' + col)

# %% [markdown]
# ##**Custom Metric**

# %%
def MCRMSE(y_true, y_pred):
    colwise_mse = tf.reduce_mean(tf.square(y_true - y_pred), axis=1)
    return tf.reduce_mean(tf.sqrt(colwise_mse), axis=-1, keepdims=True)

# %% [markdown]
# # **Read Input Files**

# %%
train_path = '/content/gdrive/MyDrive/Kaggle/train.csv'
test_path = '/content/gdrive/MyDrive/Kaggle/test.csv'

input_train_df = pd.read_csv(train_path)
input_test_df = pd.read_csv(test_path)

# input_train_df = pd.read_csv('train.csv')
# input_test_df = pd.read_csv('test.csv')

float_labels, int_map_labels = np.arange(1, 5.5, 0.5), np.arange(9)
label_map = dict(zip(float_labels, int_map_labels))

float_scaled_labels, int_scaled_labels = np.arange(1, 6, 1), np.arange(6)
label_scaled_map = dict(zip(float_scaled_labels, int_scaled_labels))

orig_train_df = copy.deepcopy(input_train_df)
orig_train_df.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %% [markdown]
# "Map" columns are basically scaled columns of the original metric values. There are total 9 levels in map columns. Original mretric columns range from 1 to 5. Through map columns, they range from 0 to 8.
#
# "Scaled" columns map numbers .5, 1.5, 2.5, 3.5 and 4.5 to nearset integers. Thus it will have range from 1 to 5.

# %%
label_map
# Out:
# {1.0: 0, 1.5: 1, 2.0: 2, 2.5: 3, 3.0: 4, 3.5: 5, 4.0: 6, 4.5: 7, 5.0: 8}

# %%
label_scaled_map
# Out:
# {1: 0, 2: 1, 3: 2, 4: 3, 5: 4}

# %% [markdown]
# # **Spliting the Data**
#
# Original test data is very limited, there are only 3 records and it does not have labels to test. So we decided to repurpose the given train data to split into train, test and validation sets.

# %%
shuffle = np.random.permutation(np.arange(orig_train_df.shape[0]))
orig_train_df = orig_train_df.iloc[shuffle]
split=(0.8,0.1,0.1)
splits = np.multiply(len(orig_train_df), split).astype(int)
df_train, df_val, df_test = np.split(orig_train_df, [splits[0], splits[0] + splits[1]])

# %%
label_cols = df_train.columns[2:]
label_rounded_cols = [col + '_rounded_val' for col in label_cols]
label_map_cols = [col + '_map' for col in label_cols]
cat_label_cols = get_cat_label_cols(label_cols)

df_train = apply_label_map(df_train, label_map, label_cols)
df_test = apply_label_map(df_test, label_map, label_cols)
df_val = apply_label_map(df_val, label_map, label_cols)

# %%
label_cols, label_rounded_cols, label_map_cols, cat_label_cols
# Out:
# (Index(['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar',
#         'conventions'],
#        dtype='object'),
#  ['cohesion_rounded_val',
#   'syntax_rounded_val',
#   'vocabulary_rounded_val',
#   'phraseology_rounded_val',
#   'grammar_rounded_val',
#   'conventions_rounded_val'],
#  ['cohesion_map',
#   'syntax_map',
#   'vocabulary_map',
#   'phraseology_map',
#   'grammar_map',
#   'conventions_map'],
#  ['cat_cohesion',
#   'cat_syntax',
#   'cat_vocabulary',
#   'cat_phraseology',
#   'cat_grammar',
#   'cat_conventions'])

# %% [markdown]
# # **Addiung Other Feature Columns**

# %%
df_train = add_feature(df_train)
df_test = add_feature(df_test)
df_val = add_feature(df_val)

# %% [markdown]
# # **EDA**

# %%
df_train.head()
# Out:
#            text_id                                          full_text  \
# 134   0A8B8F282E45  Winston Churchill once said "success consists ...
# 1470  71BA665B1B31  I think that imagination is not more important...
# 1216  5EA71157D48F  I supported that people make their own decisio...
# 3705  F7B5DF87EA1D  If we didn't take a action, What should we do?...
# 2121  9EBCC1131B13  As we have two different people, we have two t...
#
#       cohesion  syntax  vocabulary  phraseology  grammar  conventions  \
# 134        3.0     2.0         2.5          2.5      2.5          2.5
# 1470       3.0     4.0         3.0          3.5      3.5          3.0
# 1216       2.5     2.5         2.5          2.5      3.0          3.5
# 3705       2.5     2.5         3.0          3.0      3.5          3.5
# 2121       4.5     3.0         4.0          3.5      3.0          3.5
#
#       cohesion_map  syntax_map  vocabulary_map  phraseology_map  grammar_map  \
# 134              4           2               3                3            3
# 1470             4           6               4                5            5
# 1216             3           3               3                3            4
# 3705             3           3               4                4            5
# 2121             7           4               6                5            4
#
#       conventions_map  word_count  sentence_count  total_score  full_text_len  \
# 134                 3         446              15         15.0           2373
# 1470                4         226              14         20.0           1216
# 1216                5         164               7         16.5            841
# 3705                5         347              25         18.0           1876
# 2121                5         573              19         21.5           3176
#
#       cohesion_avg_score  cohesion_above_or_below_avg_flag  \
# 134             3.128676                                 0
# 1470            3.128676                                 0
# 1216            3.128676                                 0
# 3705            3.128676                                 0
# 2121            3.128676                                 1
#
#       cohesion_median_score  cohesion_above_or_below_median_flag  \
# 134                     3.0                                    0
# 1470                    3.0                                    0
# 1216                    3.0                                    0
# 3705                    3.0                                    0
# 2121                    3.0                                    1
#
#       cohesion_rounded_val  syntax_avg_score  syntax_above_or_below_avg_flag  \
# 134                    3.0           3.03133                               0
# 1470                   3.0           3.03133                               1
# 1216                   2.0           3.03133                               0
# 3705                   2.0           3.03133                               0
# 2121                   4.0           3.03133                               0
#
#       syntax_median_score  syntax_above_or_below_median_flag  \
# 134                   3.0                                  0
# 1470                  3.0                                  1
# 1216                  3.0                                  0
# 3705                  3.0                                  0
# 2121                  3.0                                  0
#
#       syntax_rounded_val  vocabulary_avg_score  \
# 134                  2.0              3.235134
# 1470                 4.0              3.235134
# 1216                 2.0              3.235134
# 3705                 2.0              3.235134
# 2121                 3.0              3.235134
#
#       vocabulary_above_or_below_avg_flag  vocabulary_median_score  \
# 134                                    0                      3.0
# 1470                                   0                      3.0
# 1216                                   0                      3.0
# 3705                                   0                      3.0
# 2121                                   1                      3.0
#
#       vocabulary_above_or_below_median_flag  vocabulary_rounded_val  \
# 134                                       0                     2.0
# 1470                                      0                     3.0
# 1216                                      0                     2.0
# 3705                                      0                     3.0
# 2121                                      1                     4.0
#
#       phraseology_avg_score  phraseology_above_or_below_avg_flag  \
# 134                3.123242                                    0
# 1470               3.123242                                    1
# 1216               3.123242                                    0
# 3705               3.123242                                    0
# 2121               3.123242                                    1
#
#       phraseology_median_score  phraseology_above_or_below_median_flag  \
# 134                        3.0                                       0
# 1470                       3.0                                       1
# 1216                       3.0                                       0
# 3705                       3.0                                       0
# 2121                       3.0                                       1
#
#       phraseology_rounded_val  grammar_avg_score  \
# 134                       2.0           3.029252
# 1470                      4.0           3.029252
# 1216                      2.0           3.029252
# 3705                      3.0           3.029252
# 2121                      4.0           3.029252
#
#       grammar_above_or_below_avg_flag  grammar_median_score  \
# 134                                 0                   3.0
# 1470                                1                   3.0
# 1216                                0                   3.0
# 3705                                1                   3.0
# 2121                                0                   3.0
#
#       grammar_above_or_below_median_flag  grammar_rounded_val  \
# 134                                    0                  2.0
# 1470                                   1                  4.0
# 1216                                   0                  3.0
# 3705                                   1                  4.0
# 2121                                   0                  3.0
#
#       conventions_avg_score  conventions_above_or_below_avg_flag  \
# 134                3.081841                                    0
# 1470               3.081841                                    0
# 1216               3.081841                                    1
# 3705               3.081841                                    1
# 2121               3.081841                                    1
#
#       conventions_median_score  conventions_above_or_below_median_flag  \
# 134                        3.0                                       0
# 1470                       3.0                                       0
# 1216                       3.0                                       1
# 3705                       3.0                                       1
# 2121                       3.0                                       1
#
#       conventions_rounded_val
# 134                       2.0
# 1470                      3.0
# 1216                      4.0
# 3705                      4.0
# 2121                      4.0

# %%
for col in label_cols:
    print(df_train[col + '_rounded_val'].unique())
# Out:
# [3. 2. 4. 1. 5.]
# [2. 4. 3. 1. 5.]
# [2. 3. 4. 1. 5.]
# [2. 4. 3. 5. 1.]
# [2. 4. 3. 1. 5.]
# [2. 3. 4. 1. 5.]

# %%
df_train.iloc[0]
# Out:
# text_id                                                                        0A8B8F282E45
# full_text                                 Winston Churchill once said "success consists ...
# cohesion                                                                                3.0
# syntax                                                                                  2.0
# vocabulary                                                                              2.5
# phraseology                                                                             2.5
# grammar                                                                                 2.5
# conventions                                                                             2.5
# cohesion_map                                                                              4
# syntax_map                                                                                2
# vocabulary_map                                                                            3
# phraseology_map                                                                           3
# grammar_map                                                                               3
# conventions_map                                                                           3
# word_count                                                                              446
# sentence_count                                                                           15
# total_score                                                                            15.0
# full_text_len                                                                          2373
# cohesion_avg_score                                                                 3.128676
# cohesion_above_or_below_avg_flag                                                          0
# cohesion_median_score                                                                   3.0
# cohesion_above_or_below_median_flag                                                       0
# cohesion_rounded_val                                                                    3.0
# syntax_avg_score                                                                    3.03133
# syntax_above_or_below_avg_flag                                                            0
# syntax_median_score                                                                     3.0
# syntax_above_or_below_median_flag                                                         0
# syntax_rounded_val                                                                      2.0
# vocabulary_avg_score                                                               3.235134
# vocabulary_above_or_below_avg_flag                                                        0
# vocabulary_median_score                                                                 3.0
# vocabulary_above_or_below_median_flag                                                     0
# vocabulary_rounded_val                                                                  2.0
# phraseology_avg_score                                                              3.123242
# phraseology_above_or_below_avg_flag                                                       0
# phraseology_median_score                                                                3.0
# phraseology_above_or_below_median_flag                                                    0
# phraseology_rounded_val                                                                 2.0
# grammar_avg_score                                                                  3.029252
# grammar_above_or_below_avg_flag                                                           0
# grammar_median_score                                                                    3.0
# grammar_above_or_below_median_flag                                                        0
# grammar_rounded_val                                                                     2.0
# conventions_avg_score                                                              3.081841
# conventions_above_or_below_avg_flag                                                       0
# conventions_median_score                                                                3.0
# conventions_above_or_below_median_flag                                                    0
# conventions_rounded_val                                                                 2.0
# Name: 134, dtype: object

# %%
df_test.head()
# Out:
#            text_id                                          full_text  \
# 3317  E587CBD5D1E4  How we know the first impression is important ...
# 3172  DF149975C610  I agree with emerson's statement. I will grow ...
# 2999  D7301CAAFAB0  When are parents gave us advice we are able to...
# 2824  CDDCA13DB734  The determination make us to do something and ...
# 310   16B9EB49892E  The should be people make their own decision, ...
#
#       cohesion  syntax  vocabulary  phraseology  grammar  conventions  \
# 3317       3.5     2.5         3.5          3.5      2.5          3.0
# 3172       3.0     3.0         3.0          3.5      2.5          3.0
# 2999       2.5     2.0         2.5          2.0      2.0          3.0
# 2824       3.5     3.0         3.0          2.5      2.5          3.5
# 310        2.5     2.5         2.5          2.0      2.5          2.0
#
#       cohesion_map  syntax_map  vocabulary_map  phraseology_map  grammar_map  \
# 3317             5           3               5                5            3
# 3172             4           4               4                5            3
# 2999             3           2               3                2            2
# 2824             5           4               4                3            3
# 310              3           3               3                2            3
#
#       conventions_map  word_count  sentence_count  total_score  full_text_len  \
# 3317                4         265               8          NaN           1350
# 3172                4         502              39          NaN           2534
# 2999                4         496              27          NaN           2449
# 2824                5         309              14          NaN           1567
# 310                 2         169               9          NaN            926
#
#       cohesion_avg_score  cohesion_above_or_below_avg_flag  \
# 3317            3.105867                                 1
# 3172            3.105867                                 0
# 2999            3.105867                                 0
# 2824            3.105867                                 1
# 310             3.105867                                 0
#
#       cohesion_median_score  cohesion_above_or_below_median_flag  \
# 3317                    3.0                                    1
# 3172                    3.0                                    0
# 2999                    3.0                                    0
# 2824                    3.0                                    1
# 310                     3.0                                    0
#
#       cohesion_rounded_val  syntax_avg_score  syntax_above_or_below_avg_flag  \
# 3317                   4.0          3.010204                               0
# 3172                   3.0          3.010204                               0
# 2999                   2.0          3.010204                               0
# 2824                   4.0          3.010204                               0
# 310                    2.0          3.010204                               0
#
#       syntax_median_score  syntax_above_or_below_median_flag  \
# 3317                  3.0                                  0
# 3172                  3.0                                  0
# 2999                  3.0                                  0
# 2824                  3.0                                  0
# 310                   3.0                                  0
#
#       syntax_rounded_val  vocabulary_avg_score  \
# 3317                 2.0              3.242347
# 3172                 3.0              3.242347
# 2999                 2.0              3.242347
# 2824                 3.0              3.242347
# 310                  2.0              3.242347
#
#       vocabulary_above_or_below_avg_flag  vocabulary_median_score  \
# 3317                                   1                      3.0
# 3172                                   0                      3.0
# 2999                                   0                      3.0
# 2824                                   0                      3.0
# 310                                    0                      3.0
#
#       vocabulary_above_or_below_median_flag  vocabulary_rounded_val  \
# 3317                                      1                     4.0
# 3172                                      0                     3.0
# 2999                                      0                     2.0
# 2824                                      0                     3.0
# 310                                       0                     2.0
#
#       phraseology_avg_score  phraseology_above_or_below_avg_flag  \
# 3317               3.067602                                    1
# 3172               3.067602                                    1
# 2999               3.067602                                    0
# 2824               3.067602                                    0
# 310                3.067602                                    0
#
#       phraseology_median_score  phraseology_above_or_below_median_flag  \
# 3317                       3.0                                       1
# 3172                       3.0                                       1
# 2999                       3.0                                       0
# 2824                       3.0                                       0
# 310                        3.0                                       0
#
#       phraseology_rounded_val  grammar_avg_score  \
# 3317                      4.0           3.042092
# 3172                      4.0           3.042092
# 2999                      2.0           3.042092
# 2824                      2.0           3.042092
# 310                       2.0           3.042092
#
#       grammar_above_or_below_avg_flag  grammar_median_score  \
# 3317                                0                   3.0
# 3172                                0                   3.0
# 2999                                0                   3.0
# 2824                                0                   3.0
# 310                                 0                   3.0
#
#       grammar_above_or_below_median_flag  grammar_rounded_val  \
# 3317                                   0                  2.0
# 3172                                   0                  2.0
# 2999                                   0                  2.0
# 2824                                   0                  2.0
# 310                                    0                  2.0
#
#       conventions_avg_score  conventions_above_or_below_avg_flag  \
# 3317               3.068878                                    0
# 3172               3.068878                                    0
# 2999               3.068878                                    0
# 2824               3.068878                                    1
# 310                3.068878                                    0
#
#       conventions_median_score  conventions_above_or_below_median_flag  \
# 3317                       3.0                                       0
# 3172                       3.0                                       0
# 2999                       3.0                                       0
# 2824                       3.0                                       1
# 310                        3.0                                       0
#
#       conventions_rounded_val
# 3317                      3.0
# 3172                      3.0
# 2999                      3.0
# 2824                      4.0
# 310                       2.0

# %%
df_val.head()
# Out:
#            text_id                                          full_text  \
# 299   16005A45A20A  There's 90% of people in the world that wants ...
# 1371  698A3F2B43B9  Have you ever thought about staring your futur...
# 3087  DB34A89420F2  I understand why you want to add an hour and t...
# 1047  4FE6EABBFC00  One topic that is frequently debated is if peo...
# 1453  6FEF6D46714D  Has it ever crossed your mind that people toda...
#
#       cohesion  syntax  vocabulary  phraseology  grammar  conventions  \
# 299        4.0     3.0         3.0          3.0      3.5          3.5
# 1371       4.0     3.0         4.0          3.5      3.5          3.0
# 3087       2.5     3.0         3.0          2.5      3.5          3.0
# 1047       5.0     4.5         4.0          4.5      4.0          4.5
# 1453       2.5     3.5         3.5          3.5      3.5          2.5
#
#       cohesion_map  syntax_map  vocabulary_map  phraseology_map  grammar_map  \
# 299              6           4               4                4            5
# 1371             6           4               6                5            5
# 3087             3           4               4                3            5
# 1047             8           7               6                7            6
# 1453             3           5               5                5            5
#
#       conventions_map  word_count  sentence_count  total_score  full_text_len  \
# 299                 5        1072              47          NaN           5449
# 1371                4         650              29          NaN           3372
# 3087                4         486              13          NaN           2508
# 1047                7         194              10          NaN           1128
# 1453                3         597              27          NaN           3239
#
#       cohesion_avg_score  cohesion_above_or_below_avg_flag  \
# 299              3.13555                                 1
# 1371             3.13555                                 1
# 3087             3.13555                                 0
# 1047             3.13555                                 1
# 1453             3.13555                                 0
#
#       cohesion_median_score  cohesion_above_or_below_median_flag  \
# 299                     3.0                                    1
# 1371                    3.0                                    1
# 3087                    3.0                                    0
# 1047                    3.0                                    1
# 1453                    3.0                                    0
#
#       cohesion_rounded_val  syntax_avg_score  syntax_above_or_below_avg_flag  \
# 299                    4.0          3.021739                               0
# 1371                   4.0          3.021739                               0
# 3087                   2.0          3.021739                               0
# 1047                   5.0          3.021739                               1
# 1453                   2.0          3.021739                               1
#
#       syntax_median_score  syntax_above_or_below_median_flag  \
# 299                   3.0                                  0
# 1371                  3.0                                  0
# 3087                  3.0                                  0
# 1047                  3.0                                  1
# 1453                  3.0                                  1
#
#       syntax_rounded_val  vocabulary_avg_score  \
# 299                  3.0              3.234015
# 1371                 3.0              3.234015
# 3087                 3.0              3.234015
# 1047                 4.0              3.234015
# 1453                 4.0              3.234015
#
#       vocabulary_above_or_below_avg_flag  vocabulary_median_score  \
# 299                                    0                      3.0
# 1371                                   1                      3.0
# 3087                                   0                      3.0
# 1047                                   1                      3.0
# 1453                                   1                      3.0
#
#       vocabulary_above_or_below_median_flag  vocabulary_rounded_val  \
# 299                                       0                     3.0
# 1371                                      1                     4.0
# 3087                                      0                     3.0
# 1047                                      1                     4.0
# 1453                                      1                     4.0
#
#       phraseology_avg_score  phraseology_above_or_below_avg_flag  \
# 299                 3.11509                                    0
# 1371                3.11509                                    1
# 3087                3.11509                                    0
# 1047                3.11509                                    1
# 1453                3.11509                                    1
#
#       phraseology_median_score  phraseology_above_or_below_median_flag  \
# 299                        3.0                                       0
# 1371                       3.0                                       1
# 3087                       3.0                                       0
# 1047                       3.0                                       1
# 1453                       3.0                                       1
#
#       phraseology_rounded_val  grammar_avg_score  \
# 299                       3.0            3.05243
# 1371                      4.0            3.05243
# 3087                      2.0            3.05243
# 1047                      4.0            3.05243
# 1453                      4.0            3.05243
#
#       grammar_above_or_below_avg_flag  grammar_median_score  \
# 299                                 1                   3.0
# 1371                                1                   3.0
# 3087                                1                   3.0
# 1047                                1                   3.0
# 1453                                1                   3.0
#
#       grammar_above_or_below_median_flag  grammar_rounded_val  \
# 299                                    1                  4.0
# 1371                                   1                  4.0
# 3087                                   1                  4.0
# 1047                                   1                  4.0
# 1453                                   1                  4.0
#
#       conventions_avg_score  conventions_above_or_below_avg_flag  \
# 299                3.086957                                    1
# 1371               3.086957                                    0
# 3087               3.086957                                    0
# 1047               3.086957                                    1
# 1453               3.086957                                    0
#
#       conventions_median_score  conventions_above_or_below_median_flag  \
# 299                        3.0                                       1
# 1371                       3.0                                       0
# 3087                       3.0                                       0
# 1047                       3.0                                       1
# 1453                       3.0                                       0
#
#       conventions_rounded_val
# 299                       4.0
# 1371                      3.0
# 3087                      3.0
# 1047                      4.0
# 1453                      2.0

# %%
df_train.shape, df_test.shape, df_val.shape
# Out:
# ((3128, 48), (392, 48), (391, 48))

# %%
df_train.describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3128.000000  3128.000000  3128.000000  3128.000000  3128.000000
# mean      3.128676     3.031330     3.235134     3.123242     3.029252
# std       0.660566     0.642023     0.582582     0.656872     0.697791
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions  cohesion_map   syntax_map  vocabulary_map  \
# count  3128.000000   3128.000000  3128.000000     3128.000000
# mean      3.081841      4.257353     4.062660        4.470269
# std       0.670081      1.321132     1.284046        1.165164
# min       1.000000      0.000000     0.000000        0.000000
# 25%       2.500000      3.000000     3.000000        4.000000
# 50%       3.000000      4.000000     4.000000        4.000000
# 75%       3.500000      5.000000     5.000000        5.000000
# max       5.000000      8.000000     8.000000        8.000000
#
#        phraseology_map  grammar_map  conventions_map   word_count  \
# count      3128.000000  3128.000000      3128.000000  3128.000000
# mean          4.246483     4.058504         4.163683   431.981458
# std           1.313744     1.395581         1.340161   191.928298
# min           0.000000     0.000000         0.000000    51.000000
# 25%           3.000000     3.000000         3.000000   294.750000
# 50%           4.000000     4.000000         4.000000   401.000000
# 75%           5.000000     5.000000         5.000000   530.000000
# max           8.000000     8.000000         8.000000  1260.000000
#
#        sentence_count  total_score  full_text_len  cohesion_avg_score  \
# count     3128.000000  3128.000000    3128.000000         3128.000000
# mean        18.186061    18.629476    2341.242327            3.128676
# std         10.180678     3.355094    1029.872033            0.000000
# min          1.000000     6.000000     269.000000            3.128676
# 25%         10.000000    16.000000    1601.000000            3.128676
# 50%         17.000000    18.500000    2174.000000            3.128676
# 75%         24.000000    21.000000    2869.250000            3.128676
# max         99.000000    30.000000    6044.000000            3.128676
#
#        cohesion_above_or_below_avg_flag  cohesion_median_score  \
# count                       3128.000000                 3128.0
# mean                           0.429348                    3.0
# std                            0.495062                    0.0
# min                            0.000000                    3.0
# 25%                            0.000000                    3.0
# 50%                            0.000000                    3.0
# 75%                            1.000000                    3.0
# max                            1.000000                    3.0
#
#        cohesion_above_or_below_median_flag  cohesion_rounded_val  \
# count                          3128.000000           3128.000000
# mean                              0.429348              3.143542
# std                               0.495062              0.853247
# min                               0.000000              1.000000
# 25%                               0.000000              2.000000
# 50%                               0.000000              3.000000
# 75%                               1.000000              4.000000
# max                               1.000000              5.000000
#
#        syntax_avg_score  syntax_above_or_below_avg_flag  syntax_median_score  \
# count        3128.00000                     3128.000000               3128.0
# mean            3.03133                        0.351662                  3.0
# std             0.00000                        0.477566                  0.0
# min             3.03133                        0.000000                  3.0
# 25%             3.03133                        0.000000                  3.0
# 50%             3.03133                        0.000000                  3.0
# 75%             3.03133                        1.000000                  3.0
# max             3.03133                        1.000000                  3.0
#
#        syntax_above_or_below_median_flag  syntax_rounded_val  \
# count                        3128.000000         3128.000000
# mean                            0.351662            3.023338
# std                             0.477566            0.838645
# min                             0.000000            1.000000
# 25%                             0.000000            2.000000
# 50%                             0.000000            3.000000
# 75%                             1.000000            4.000000
# max                             1.000000            5.000000
#
#        vocabulary_avg_score  vocabulary_above_or_below_avg_flag  \
# count          3.128000e+03                         3128.000000
# mean           3.235134e+00                            0.445332
# std            4.441602e-16                            0.497082
# min            3.235134e+00                            0.000000
# 25%            3.235134e+00                            0.000000
# 50%            3.235134e+00                            0.000000
# 75%            3.235134e+00                            1.000000
# max            3.235134e+00                            1.000000
#
#        vocabulary_median_score  vocabulary_above_or_below_median_flag  \
# count                   3128.0                            3128.000000
# mean                       3.0                               0.445332
# std                        0.0                               0.497082
# min                        3.0                               0.000000
# 25%                        3.0                               0.000000
# 50%                        3.0                               0.000000
# 75%                        3.0                               1.000000
# max                        3.0                               1.000000
#
#        vocabulary_rounded_val  phraseology_avg_score  \
# count             3128.000000           3.128000e+03
# mean                 3.283887           3.123242e+00
# std                  0.755728           4.441602e-16
# min                  1.000000           3.123242e+00
# 25%                  3.000000           3.123242e+00
# 50%                  3.000000           3.123242e+00
# 75%                  4.000000           3.123242e+00
# max                  5.000000           3.123242e+00
#
#        phraseology_above_or_below_avg_flag  phraseology_median_score  \
# count                          3128.000000                    3128.0
# mean                              0.417519                       3.0
# std                               0.493229                       0.0
# min                               0.000000                       3.0
# 25%                               0.000000                       3.0
# 50%                               0.000000                       3.0
# 75%                               1.000000                       3.0
# max                               1.000000                       3.0
#
#        phraseology_above_or_below_median_flag  phraseology_rounded_val  \
# count                             3128.000000              3128.000000
# mean                                 0.417519                 3.130754
# std                                  0.493229                 0.847789
# min                                  0.000000                 1.000000
# 25%                                  0.000000                 2.000000
# 50%                                  0.000000                 3.000000
# 75%                                  1.000000                 4.000000
# max                                  1.000000                 5.000000
#
#        grammar_avg_score  grammar_above_or_below_avg_flag  \
# count        3128.000000                      3128.000000
# mean            3.029252                         0.378836
# std             0.000000                         0.485175
# min             3.029252                         0.000000
# 25%             3.029252                         0.000000
# 50%             3.029252                         0.000000
# 75%             3.029252                         1.000000
# max             3.029252                         1.000000
#
#        grammar_median_score  grammar_above_or_below_median_flag  \
# count                3128.0                         3128.000000
# mean                    3.0                            0.378836
# std                     0.0                            0.485175
# min                     3.0                            0.000000
# 25%                     3.0                            0.000000
# 50%                     3.0                            0.000000
# 75%                     3.0                            1.000000
# max                     3.0                            1.000000
#
#        grammar_rounded_val  conventions_avg_score  \
# count          3128.000000           3.128000e+03
# mean              3.018862           3.081841e+00
# std               0.876785           4.441602e-16
# min               1.000000           3.081841e+00
# 25%               2.000000           3.081841e+00
# 50%               3.000000           3.081841e+00
# 75%               4.000000           3.081841e+00
# max               5.000000           3.081841e+00
#
#        conventions_above_or_below_avg_flag  conventions_median_score  \
# count                          3128.000000                    3128.0
# mean                              0.397059                       3.0
# std                               0.489367                       0.0
# min                               0.000000                       3.0
# 25%                               0.000000                       3.0
# 50%                               0.000000                       3.0
# 75%                               1.000000                       3.0
# max                               1.000000                       3.0
#
#        conventions_above_or_below_median_flag  conventions_rounded_val
# count                             3128.000000              3128.000000
# mean                                 0.397059                 3.086637
# std                                  0.489367                 0.855674
# min                                  0.000000                 1.000000
# 25%                                  0.000000                 2.000000
# 50%                                  0.000000                 3.000000
# 75%                                  1.000000                 4.000000
# max                                  1.000000                 5.000000

# %%
df_train.columns
# Out:
# Index(['text_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions', 'cohesion_map', 'syntax_map',
#        'vocabulary_map', 'phraseology_map', 'grammar_map', 'conventions_map',
#        'word_count', 'sentence_count', 'total_score', 'full_text_len',
#        'cohesion_avg_score', 'cohesion_above_or_below_avg_flag',
#        'cohesion_median_score', 'cohesion_above_or_below_median_flag',
#        'cohesion_rounded_val', 'syntax_avg_score',
#        'syntax_above_or_below_avg_flag', 'syntax_median_score',
#        'syntax_above_or_below_median_flag', 'syntax_rounded_val',
#        'vocabulary_avg_score', 'vocabulary_above_or_below_avg_flag',
#        'vocabulary_median_score', 'vocabulary_above_or_below_median_flag',
#        'vocabulary_rounded_val', 'phraseology_avg_score',
#        'phraseology_above_or_below_avg_flag', 'phraseology_median_score',
#        'phraseology_above_or_below_median_flag', 'phraseology_rounded_val',
#        'grammar_avg_score', 'grammar_above_or_below_avg_flag',
#        'grammar_median_score', 'grammar_above_or_below_median_flag',
#        'grammar_rounded_val', 'conventions_avg_score',
#        'conventions_above_or_below_avg_flag', 'conventions_median_score',
#        'conventions_above_or_below_median_flag', 'conventions_rounded_val'],
#       dtype='object')

# %% [markdown]
# ## **Unique Values for Each Label**

# %%
get_unique_values_for_labels(df_train, label_cols)
# Out:
# Unique Values in Each Metric:
# ==================================================
# cohesion: [3.  2.5 4.5 2.  3.5 4.  1.  5.  1.5]
# syntax: [2.  4.  2.5 3.  3.5 4.5 1.  5.  1.5]
# vocabulary: [2.5 3.  4.  3.5 2.  4.5 1.5 1.  5. ]
# phraseology: [2.5 3.5 3.  4.  5.  2.  4.5 1.  1.5]
# grammar: [2.5 3.5 3.  2.  4.5 4.  1.  5.  1.5]
# conventions: [2.5 3.  3.5 4.  2.  4.5 1.  1.5 5. ]

# %% [markdown]
# ## **Unique Values for Each Rounded Label**

# %%
get_unique_values_for_labels(df_train, label_rounded_cols)
# Out:
# Unique Values in Each Metric:
# ==================================================
# cohesion_rounded_val: [3. 2. 4. 1. 5.]
# syntax_rounded_val: [2. 4. 3. 1. 5.]
# vocabulary_rounded_val: [2. 3. 4. 1. 5.]
# phraseology_rounded_val: [2. 4. 3. 5. 1.]
# grammar_rounded_val: [2. 4. 3. 1. 5.]
# conventions_rounded_val: [2. 3. 4. 1. 5.]

# %% [markdown]
# ## **Value Counts for Each Label**

# %%
get_value_counts_for_labels(df_train, label_cols)
# Out:
# Counts for Each Metric:
# ==================================================
# Column: cohesion
# 1.0      8
# 1.5     21
# 5.0     22
# 4.5     90
# 2.0    251
# 4.0    441
# 2.5    628
# 3.5    790
# 3.0    877
# Name: cohesion, dtype: int64
# *****
# Column: syntax
# 1.0      7
# 5.0     15
# 1.5     24
# 4.5     81
# 4.0    307
# 2.0    314
# 2.5    690
# 3.5    697
# 3.0    993
# Name: syntax, dtype: int64
# *****
# Column: vocabulary
# 1.0       2
# 1.5      10
# 5.0      34
# 4.5      91
# 2.0      98
# 2.5     427
# 4.0     455
# 3.5     813
# 3.0    1198
# Name: vocabulary, dtype: int64
# *****
# Column: phraseology
# 1.0      7
# 1.5      8
# 5.0     21
# 4.5     90
# 2.0    276
# 4.0    446
# 2.5    620
# 3.5    749
# 3.0    911
# Name: phraseology, dtype: int64
# *****
# Column: grammar
# 1.0      5
# 1.5     14
# 5.0     21
# 4.5    109
# 4.0    351
# 2.0    449
# 2.5    674
# 3.5    704
# 3.0    801
# Name: grammar, dtype: int64
# *****
# Column: conventions
# 1.0     14
# 1.5     15
# 5.0     18
# 4.5     96
# 2.0    317
# 4.0    388
# 2.5    629
# 3.5    740
# 3.0    911
# Name: conventions, dtype: int64
# *****

# %%
plot_count(df_train, label_cols)

# %% [markdown]
# ## **Value Counts for Each Rounded Label**

# %%
get_value_counts_for_labels(df_train, label_rounded_cols)
# Out:
# Counts for Each Metric:
# ==================================================
# Column: cohesion_rounded_val
# 1.0       8
# 5.0      22
# 3.0     877
# 2.0     900
# 4.0    1321
# Name: cohesion_rounded_val, dtype: int64
# *****
# Column: syntax_rounded_val
# 1.0       7
# 5.0      15
# 3.0     993
# 2.0    1028
# 4.0    1085
# Name: syntax_rounded_val, dtype: int64
# *****
# Column: vocabulary_rounded_val
# 1.0       2
# 5.0      34
# 2.0     535
# 3.0    1198
# 4.0    1359
# Name: vocabulary_rounded_val, dtype: int64
# *****
# Column: phraseology_rounded_val
# 1.0       7
# 5.0      21
# 2.0     904
# 3.0     911
# 4.0    1285
# Name: phraseology_rounded_val, dtype: int64
# *****
# Column: grammar_rounded_val
# 1.0       5
# 5.0      21
# 3.0     801
# 2.0    1137
# 4.0    1164
# Name: grammar_rounded_val, dtype: int64
# *****
# Column: conventions_rounded_val
# 1.0      14
# 5.0      18
# 3.0     911
# 2.0     961
# 4.0    1224
# Name: conventions_rounded_val, dtype: int64
# *****

# %%
plot_count(df_train, label_rounded_cols)

# %% [markdown]
# ## **Full Text Length Stats**

# %%
df_train.full_text.str.len().describe()
# Out:
# count    3128.000000
# mean     2341.242327
# std      1029.872033
# min       269.000000
# 25%      1601.000000
# 50%      2174.000000
# 75%      2869.250000
# max      6044.000000
# Name: full_text, dtype: float64

# %% [markdown]
# ## **Word Count Stats**

# %%
df_train.word_count.describe()
# Out:
# count    3128.000000
# mean      431.981458
# std       191.928298
# min        51.000000
# 25%       294.750000
# 50%       401.000000
# 75%       530.000000
# max      1260.000000
# Name: word_count, dtype: float64

# %% [markdown]
# ## **Sentence Count Stats**

# %%
df_train.sentence_count.describe()
# Out:
# count    3128.000000
# mean       18.186061
# std        10.180678
# min         1.000000
# 25%        10.000000
# 50%        17.000000
# 75%        24.000000
# max        99.000000
# Name: sentence_count, dtype: float64

# %%
df_train[df_train.sentence_count == 1][['full_text']]
# Out:
#                                               full_text
# 1080  dear TEACHER_NAME i think the you should let s...
# 272   The year book is for to not forget anything an...
# 39    my name is Generic_Name and my story is about ...
# 1848  well people has deferent opinion's about commu...
# 3557  is number 1 because same time samtin import is...
# 800   I  disagree that first impressions are almost ...
# 3607  Being yourself doesn't depends in how people s...
# 3134  Mr; Generic_Name please let me explain The ben...
# 2250  when people ask for advice, sometimes seeking ...
# 1139  A small kindness can change a person because i...
# 532   I agree because is important to have a positiv...
# 1921  Dear principal i am writhing this letter, to a...
# 1373  We can't remove the impressions of the mind, a...
# 2835  its aboute the plans of the half day i agree b...
# 2933  yes becuase students would have more time to t...
# 842   Example :  Some student in High School try to ...

# %% [markdown]
# # **Visualization**

# %% [markdown]
# ## **Corelation Matrix of the Label Columns**

# %%
corr = df_train[label_cols].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype = bool))

sns.set(rc = {"figure.figsize": (10, 8)})

sns.heatmap(corr, 
            annot = True, 
            cmap = "coolwarm", 
            mask = mask,
            fmt  = ".5f")
plt.show()

# %% [markdown]
# ## **Essay Length, Word Count, Total Score, Sentence Count Distribution**
#
# Essay length, word count and sentence count diostributions have normal shape, though left skewed. Total score distribution looks bi-modal.

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,4,1)
sns.histplot(data=df_train, x='word_count', kde=True)
plt.axvline(x=df_train['word_count'].mean(),color='red')
plt.axvline(x=df_train['word_count'].median(),color='black')
plt.xlabel('Word Count Distribution',fontsize=12)
plt.title('Word Count Distribution',fontsize=16)

plt.subplot(1,4,2)
sns.histplot(data=df_train, x='full_text_len', kde=True)
plt.axvline(x=df_train['full_text_len'].mean(),color='red')
plt.axvline(x=df_train['full_text_len'].median(),color='black')
plt.xlabel('Full Text Length Distribution',fontsize=12)
plt.title('Full Text Length Distribution',fontsize=16)

plt.subplot(1,4,3)
sns.histplot(data=df_train, x='total_score', kde=True)
plt.axvline(x=df_train['total_score'].mean(),color='red')
plt.axvline(x=df_train['total_score'].median(),color='black')
plt.xlabel('Total Score Distribution',fontsize=12)
plt.title('Total Score Distribution',fontsize=16)

plt.subplot(1,4,4)
sns.histplot(data=df_train, x='sentence_count', kde=True)
plt.axvline(x=df_train['sentence_count'].mean(),color='red')
plt.axvline(x=df_train['sentence_count'].median(),color='black')
plt.xlabel('Sentence Count Distribution',fontsize=12)
plt.title('Sentence Count Distribution',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Sentence Count Distribution')

# %% [markdown]
# ## **Word Count Vs Individual Label Scores**

# %%
get_histogram_for_col(df_train, label_cols, 'word_count')

# %% [markdown]
# ## **Word Count Vs Individual Rounded Label Scores**

# %%
get_histogram_for_col(df_train, label_rounded_cols, 'word_count')

# %% [markdown]
# ## **Sentence Count Vs Individual Label Scores**

# %%
get_histogram_for_col(df_train, label_cols, 'sentence_count')

# %% [markdown]
# ## **Sentence Count Vs Individual Rounded Label Scores**

# %%
get_histogram_for_col(df_train, label_rounded_cols, 'sentence_count')

# %% [markdown]
# ## **Distribution of Labels Above and Below Average in the Respective Category**

# %%
get_count_plot_for_ind_col(df_train, '_above_or_below_avg_flag', label_cols)

# %% [markdown]
# ## **Distribution of Labels Above and Below Median in the Respective Category**

# %%
get_count_plot_for_ind_col(df_train, '_above_or_below_median_flag', label_cols)

# %% [markdown]
# For all the labels we see that most of the label values are below average and median values.

# %% [markdown]
# ## **Distribution of Labels**

# %%
fig, ax = plt.subplots(1, len(label_cols), figsize=(40,10))

for idx, label in enumerate(label_cols):
    sns.distplot(x = df_train[label],
                 ax = ax[idx]
                )
    ax[idx].set_title(label)
    #plt.show(block = False)

# %% [markdown]
# ## **Average Score Per Label**

# %%
get_barplot_for_each_label(df_train, label_cols, '_avg_score')

# %% [markdown]
# ## **Median Score Per Label**

# %%
get_barplot_for_each_label(df_train, label_cols, '_median_score')

# %% [markdown]
# ## **Most Frequent Words**

# %%
text = df_train[df_train[label_cols].sum(axis=1)==30]['full_text'].values[0]
word_cloud = WordCloud(stopwords=STOPWORDS, colormap='Pastel1', collocations=False, width=1200, height=700, background_color = "black").generate(text)
plt.figure(figsize=(20,8))
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # **Model Building**

# %%
#make it easier to use a variety of BERT subword models
model_checkpoint = 'bert-base-cased'   # case sensitive (care about upper and lower case)
bert_tokenizer = BertTokenizer.from_pretrained(model_checkpoint)
MAX_LENGTH = 512

# %% [markdown]
# ## **Generate Input Embeddings - Train/Validation/Test Set**

# %%
def get_label_dict(df, col_list_1, col_list_2):
    return dict(zip(col_list_2, get_label_values(df, col_list_1)))

# %%
X_train, X_val, X_test = df_train['full_text'], df_val['full_text'], df_test['full_text']
y_train, y_val, y_test = np.array(df_train[label_cols]), np.array(df_val[label_cols]), np.array(df_test[label_cols])

# Handling map columns, this maintains the same number of levels as present in the original kpi sets.
y_train_map, y_val_map, y_test_map = np.array(df_train[label_map_cols]), np.array(df_val[label_map_cols]), np.array(df_test[label_map_cols])
y_train_map_combined = get_label_dict(df_train, label_map_cols, cat_label_cols)
y_test_map_combined = get_label_dict(df_test, label_map_cols, cat_label_cols)
y_val_map_combined = get_label_dict(df_val, label_map_cols, cat_label_cols)

# Handling scaled values. Here we are converting the decimal values to nearest integers.
# Thus .5, 1.5, 2.5, 3.5 and 4.5 map to 1, 2, 3, 4 and 5 respectively.
y_train_scaled, y_val_scaled, y_test_scaled = np.array(df_train[label_rounded_cols]), np.array(df_val[label_rounded_cols]), np.array(df_test[label_rounded_cols])
y_train_scaled_combined = get_label_dict(df_train, label_rounded_cols, cat_label_cols)
y_test_scaled_combined = get_label_dict(df_test, label_rounded_cols, cat_label_cols)
y_val_scaled_combined = get_label_dict(df_val, label_rounded_cols, cat_label_cols)

# %%
y_train_scaled_combined
# Out:
# {'cat_cohesion': array([3., 3., 2., ..., 3., 3., 4.]),
#  'cat_syntax': array([2., 4., 2., ..., 2., 3., 4.]),
#  'cat_vocabulary': array([2., 3., 2., ..., 2., 3., 4.]),
#  'cat_phraseology': array([2., 4., 2., ..., 2., 2., 5.]),
#  'cat_grammar': array([2., 4., 3., ..., 2., 2., 4.]),
#  'cat_conventions': array([2., 3., 4., ..., 3., 4., 4.])}

# %%
y_train_map_combined
# Out:
# {'cat_cohesion': array([4, 4, 3, ..., 4, 4, 6]),
#  'cat_syntax': array([2, 6, 3, ..., 3, 4, 7]),
#  'cat_vocabulary': array([3, 4, 3, ..., 3, 4, 7]),
#  'cat_phraseology': array([3, 5, 3, ..., 3, 3, 8]),
#  'cat_grammar': array([3, 5, 4, ..., 3, 3, 6]),
#  'cat_conventions': array([3, 4, 5, ..., 4, 5, 7])}

# %%
train_encodings = bert_tokenizer(X_train.tolist(), dtype="int32", truncation=True, padding=True, max_length=MAX_LENGTH, return_tensors='tf')
val_encodings = bert_tokenizer(X_val.tolist(), dtype="int32", truncation=True, padding=True, max_length=MAX_LENGTH, return_tensors='tf')
test_encodings = bert_tokenizer(X_test.tolist(), dtype="int32", truncation=True, padding=True, max_length=MAX_LENGTH, return_tensors='tf')

# %%
classification_loss_dict = {label : tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False) for label in cat_label_cols}
classification_loss_dict
# Out:
# {'cat_cohesion': <keras.losses.SparseCategoricalCrossentropy at 0x7eff62801820>,
#  'cat_syntax': <keras.losses.SparseCategoricalCrossentropy at 0x7eff628015e0>,
#  'cat_vocabulary': <keras.losses.SparseCategoricalCrossentropy at 0x7eff62801760>,
#  'cat_phraseology': <keras.losses.SparseCategoricalCrossentropy at 0x7eff62801b50>,
#  'cat_grammar': <keras.losses.SparseCategoricalCrossentropy at 0x7eff62801670>,
#  'cat_conventions': <keras.losses.SparseCategoricalCrossentropy at 0x7eff62801910>}

# %%
classification_metrics_dict = {label : 'accuracy' for label in cat_label_cols}
classification_metrics_dict
# Out:
# {'cat_cohesion': 'accuracy',
#  'cat_syntax': 'accuracy',
#  'cat_vocabulary': 'accuracy',
#  'cat_phraseology': 'accuracy',
#  'cat_grammar': 'accuracy',
#  'cat_conventions': 'accuracy'}

# %%
regression_loss_dict = {label : 'huber_loss' for label in label_cols}
regression_loss_dict
# Out:
# {'cohesion': 'huber_loss',
#  'syntax': 'huber_loss',
#  'vocabulary': 'huber_loss',
#  'phraseology': 'huber_loss',
#  'grammar': 'huber_loss',
#  'conventions': 'huber_loss'}

# %%
regression_metrics_dict = {label : tf.keras.metrics.RootMeanSquaredError() for label in label_cols}
regression_metrics_dict
# Out:
# {'cohesion': <keras.metrics.metrics.RootMeanSquaredError at 0x7eff70c57f40>,
#  'syntax': <keras.metrics.metrics.RootMeanSquaredError at 0x7eff7dc5ce80>,
#  'vocabulary': <keras.metrics.metrics.RootMeanSquaredError at 0x7eff73f89f70>,
#  'phraseology': <keras.metrics.metrics.RootMeanSquaredError at 0x7eff7131a490>,
#  'grammar': <keras.metrics.metrics.RootMeanSquaredError at 0x7eff7143f640>,
#  'conventions': <keras.metrics.metrics.RootMeanSquaredError at 0x7eff6238ffa0>}

# %% [markdown]
# # Heesuk's Questions:
# - why **huber loss** (could use RMSE as well)?
# - do we need to set **activation=None** for regression instead?
# - need to consistent with **MAX_LENGTH=512** across all owners => let's be consistent in applyiing the same values for hyperparam
#
#   - diff num of unfreezing layers = 2, 6, or 12
#   - batch size = 8 or 16
#   - diff learning rate = 0.00001, 0.00005, or 0.0001
#   - size of hidden layer = upto 3 layers, units = up to 512
#   - dropout rate = 0.1, 0.3, or 0.5
#   - num_classes = 5 (np.ceil) 1-5 or 9 (0-8):
#     - For regression - use 9 classes as is
# - Use the same features (mean score, median score etc.)
# - Test train/test vs test/valid/test split

# %%
def create_bert_model(checkpoint = model_checkpoint,
                      num_classes = 9,   # [1, 1.5, 2, 2.5....4.5, 5]: 9 classes
                      number_of_hidden_layer = 1,
                      hidden_layer_node_count = 256,
                      dropout = 0.3,
                      learning_rate = 0.00001,
                      trainable_flag = True,
                      retrain_layer_count = 999,#All layers are trainable
                      classification_regression_flag = 'C',
                      max_length = MAX_LENGTH):
    """
    Build a simple classification model with BERT. Use the Pooler Output for classification purposes.
    """
    set_config_param()
    bert_model = TFBertModel.from_pretrained(checkpoint, name = 'bert_model')    
    if trainable_flag:
        if retrain_layer_count == 999:
            # Train all layers of the BERT model
            bert_model.trainable = True         
        else:
            retrain_layers_list = []
            for retrain_layer_number in range(retrain_layer_count):
                retrain_layers_list.append('retrain_layer_' + str(retrain_layer_number)) 
            print('retrain layers: ', retrain_layers_list)

            for weight in bert_model.weights:
                if not any([x in weight.name for layer in retrain_layers_list]):
                    #print('freezing: ', w)
                    weight._trainable = False
    else:
        # Freeze all layers of pre-trained BERT model
        bert_model.trainable = False 
    
    # Input layer
    input_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='input_ids_layer')
    token_type_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='token_type_ids_layer')
    attention_mask = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='attention_mask_layer')

    bert_inputs = {'input_ids': input_ids,
                   'token_type_ids': token_type_ids,
                   'attention_mask': attention_mask}
                   
    # Bert output: being used as an input feature in the classification model below
    bert_out = bert_model(bert_inputs)        # full features as an input to the following classification model
    # pooler_output = bert_out[1]             # one vector for each
    cls_token = bert_out[0][:, 0, :]          # give us a raw CLS tokens

    # =========== END generate "input features" using BERT tokenizer ==================================

    # =========== BEGIN build a "multi-classification model" below passing the BERT input features ======
    layer_list = []
    for hidden_layer_number in range(number_of_hidden_layer):
        if hidden_layer_number == 0:
            hidden_layer = tf.keras.layers.Dense(units = hidden_layer_node_count
                                               , activation = 'relu'
                                               , name = 'hidden_layer_' + str(hidden_layer_number + 1)
                                                )(cls_token)
        else:
            hidden_layer = tf.keras.layers.Dense(units = hidden_layer_node_count
                                               , activation = 'relu'
                                               , name = 'hidden_layer_' + str(hidden_layer_number + 1)
                                                )(layer_list[-1])
        layer_list.append(hidden_layer)
        #dropout_layer = tf.keras.layers.Dropout(dropout, name = 'dropout_layer_' + str(hidden_layer_number + 1))(hidden_layer) 
        #layer_list.append(dropout_layer)

    if number_of_hidden_layer > 0:
        dropout_layer = tf.keras.layers.Dropout(dropout, name = 'dropout_layer')(hidden_layer) 
        layer_list.append(dropout_layer)

    if classification_regression_flag == 'C':
        # Output classification layer
        classification_cohesion = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_cohesion')(layer_list[-1]) 
        classification_syntax = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_syntax')(layer_list[-1])
        classification_vocabulary = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_vocabulary')(layer_list[-1])
        classification_phraseology = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_phraseology')(layer_list[-1])
        classification_grammar = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_grammar')(layer_list[-1])
        classification_conventions = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_conventions')(layer_list[-1])

        outputs = [classification_cohesion, 
                   classification_syntax, 
                   classification_vocabulary, 
                   classification_phraseology, 
                   classification_grammar, 
                   classification_conventions
                  ]
        classification_model = tf.keras.Model(inputs = [input_ids, 
                                                        token_type_ids, 
                                                        attention_mask
                                                       ], 
                                              outputs = outputs
                                             )
        classification_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate),
                                     loss = classification_loss_dict,
                                     metrics = classification_metrics_dict
                                    )                
        return classification_model

    elif classification_regression_flag == 'R':

        # Output regression layer
        regression_cohesion = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_cohesion')(layer_list[-1]) 
        regression_syntax = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_syntax')(layer_list[-1])
        regression_vocabulary = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_vocabulary')(layer_list[-1])
        regression_phraseology = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_phraseology')(layer_list[-1])
        regression_grammar = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_grammar')(layer_list[-1])
        regression_conventions = tf.keras.layers.Dense(num_classes, activation = 'softmax', name = 'cat_conventions')(layer_list[-1])

        outputs = [regression_cohesion, 
                   regression_syntax, 
                   regression_vocabulary, 
                   regression_phraseology, 
                   regression_grammar, 
                   regression_conventions
                  ]
        regression_model = tf.keras.Model(inputs = [input_ids, 
                                                    token_type_ids, 
                                                    attention_mask
                                                   ], 
                                          outputs = outputs
                                         )
        regression_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate),
                                 loss = regression_loss_dict,
                                 metrics = regression_metrics_dict
                                )                
        return regression_model

# %% [markdown]
# ## **"bert_classification_model_1" is the baseline classification model with multilabel multi output(1..9). We are retraining the pre-trained model.**

# %%
bert_classification_model_1 = create_bert_model(checkpoint = model_checkpoint,
                                                num_classes = 9,   # [1, 1.5, 2, 2.5....4.5, 5]: 9 classes
                                                number_of_hidden_layer = 1,
                                                hidden_layer_node_count = 128,
                                                dropout = 0.3,
                                                learning_rate = 0.00001,
                                                trainable_flag = True,
                                                retrain_layer_count = 999,#All layers trainable
                                                classification_regression_flag = 'C',
                                                max_length = MAX_LENGTH
                                              )

print(bert_classification_model_1.summary())
# Out:
# Downloading tf_model.h5:   0%|          | 0.00/527M [00:00<?, ?B/s]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  attention_mask_layer (InputLay  [(None, 512)]       0           []
#  er)
#
#  input_ids_layer (InputLayer)   [(None, 512)]        0           []
#
#  token_type_ids_layer (InputLay  [(None, 512)]       0           []
#  er)
#
#  bert_model (TFBertModel)       TFBaseModelOutputWi  108310272   ['attention_mask_layer[0][0]',
#                                 thPoolingAndCrossAt               'input_ids_layer[0][0]',
#                                 tentions(last_hidde               'token_type_ids_layer[0][0]']
#                                 n_state=(None, 512,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  tf.__operators__.getitem (Slic  (None, 768)         0           ['bert_model[0][0]']
#  ingOpLambda)
#
#  hidden_layer_1 (Dense)         (None, 128)          98432       ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  dropout_layer (Dropout)        (None, 128)          0           ['hidden_layer_1[0][0]']
#
#  cat_cohesion (Dense)           (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_syntax (Dense)             (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_vocabulary (Dense)         (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_phraseology (Dense)        (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_grammar (Dense)            (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_conventions (Dense)        (None, 9)            1161        ['dropout_layer[0][0]']
#
# ==================================================================================================
# Total params: 108,415,670
# Trainable params: 108,415,670
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
keras.utils.plot_model(bert_classification_model_1, show_shapes=False, show_dtype=False, show_layer_names=True, dpi=90)

# %%
bert_classification_model_1_history = bert_classification_model_1.fit([train_encodings.input_ids, 
                                                                       train_encodings.token_type_ids, 
                                                                       train_encodings.attention_mask
                                                                      ], 
                                                                      y_train_map_combined,   
                                                                      validation_data =([val_encodings.input_ids, 
                                                                                         val_encodings.token_type_ids, 
                                                                                         val_encodings.attention_mask
                                                                                        ], 
                                                                                        y_val_map_combined
                                                                                      ),    
                                                                      batch_size = 8, 
                                                                      epochs = 5
                                                                     )                                                  
bert_classification_model_1_history_df = pd.DataFrame(bert_classification_model_1_history.history)
bert_classification_model_1_history_df.T
# Out:
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 391/391 [==============================] - 433s 1s/step - loss: 11.2657 - cat_cohesion_loss: 1.8421 - cat_syntax_loss: 1.7801 - cat_vocabulary_loss: 1.7151 - cat_phraseology_loss: 2.0678 - cat_grammar_loss: 1.9386 - cat_conventions_loss: 1.9220 - cat_cohesion_accuracy: 0.2970 - cat_syntax_accuracy: 0.3015 - cat_vocabulary_accuracy: 0.3427 - cat_phraseology_accuracy: 0.1931 - cat_grammar_accuracy: 0.2666 - cat_conventions_accuracy: 0.2580 - val_loss: 9.8755 - val_cat_cohesion_loss: 1.6496 - val_cat_syntax_loss: 1.6081 - val_cat_vocabulary_loss: 1.5151 - val_cat_phraseology_loss: 1.7593 - val_cat_grammar_loss: 1.6896 - val_cat_conventions_loss: 1.6538 - val_cat_cohesion_accuracy: 0.3223 - val_cat_syntax_accuracy: 0.3683 - val_cat_vocabulary_accuracy: 0.4834 - val_cat_phraseology_accuracy: 0.2864 - val_cat_grammar_accuracy: 0.3299 - val_cat_conventions_accuracy: 0.3632
# Epoch 2/5
# 391/391 [==============================] - 391s 1s/step - loss: 10.2951 - cat_cohesion_loss: 1.7478 - cat_syntax_loss: 1.6478 - cat_vocabulary_loss: 1.5748 - cat_phraseology_loss: 1.8224 - cat_grammar_loss: 1.8112 - cat_conventions_loss: 1.6912 - cat_cohesion_accuracy: 0.3165 - cat_syntax_accuracy: 0.3389 - cat_vocabulary_accuracy: 0.3945 - cat_phraseology_accuracy: 0.3005 - cat_grammar_accuracy: 0.3095 - cat_conventions_accuracy: 0.3398 - val_loss: 9.2767 - val_cat_cohesion_loss: 1.5486 - val_cat_syntax_loss: 1.5384 - val_cat_vocabulary_loss: 1.4300 - val_cat_phraseology_loss: 1.6431 - val_cat_grammar_loss: 1.5929 - val_cat_conventions_loss: 1.5238 - val_cat_cohesion_accuracy: 0.3836 - val_cat_syntax_accuracy: 0.3555 - val_cat_vocabulary_accuracy: 0.4527 - val_cat_phraseology_accuracy: 0.3862 - val_cat_grammar_accuracy: 0.3939 - val_cat_conventions_accuracy: 0.4041
# Epoch 3/5
# 391/391 [==============================] - 395s 1s/step - loss: 9.6970 - cat_cohesion_loss: 1.6598 - cat_syntax_loss: 1.5343 - cat_vocabulary_loss: 1.4870 - cat_phraseology_loss: 1.7033 - cat_grammar_loss: 1.6960 - cat_conventions_loss: 1.6166 - cat_cohesion_accuracy: 0.3309 - cat_syntax_accuracy: 0.3763 - cat_vocabulary_accuracy: 0.4214 - cat_phraseology_accuracy: 0.3334 - cat_grammar_accuracy: 0.3382 - cat_conventions_accuracy: 0.3501 - val_loss: 9.3116 - val_cat_cohesion_loss: 1.5673 - val_cat_syntax_loss: 1.5478 - val_cat_vocabulary_loss: 1.4521 - val_cat_phraseology_loss: 1.5845 - val_cat_grammar_loss: 1.6130 - val_cat_conventions_loss: 1.5469 - val_cat_cohesion_accuracy: 0.3120 - val_cat_syntax_accuracy: 0.3811 - val_cat_vocabulary_accuracy: 0.4373 - val_cat_phraseology_accuracy: 0.3939 - val_cat_grammar_accuracy: 0.3836 - val_cat_conventions_accuracy: 0.3632
# Epoch 4/5
# 391/391 [==============================] - 390s 998ms/step - loss: 9.1601 - cat_cohesion_loss: 1.5881 - cat_syntax_loss: 1.4665 - cat_vocabulary_loss: 1.4125 - cat_phraseology_loss: 1.5656 - cat_grammar_loss: 1.6043 - cat_conventions_loss: 1.5232 - cat_cohesion_accuracy: 0.3616 - cat_syntax_accuracy: 0.3945 - cat_vocabulary_accuracy: 0.4476 - cat_phraseology_accuracy: 0.4031 - cat_grammar_accuracy: 0.3683 - cat_conventions_accuracy: 0.3942 - val_loss: 8.9552 - val_cat_cohesion_loss: 1.5310 - val_cat_syntax_loss: 1.5196 - val_cat_vocabulary_loss: 1.3893 - val_cat_phraseology_loss: 1.5173 - val_cat_grammar_loss: 1.5497 - val_cat_conventions_loss: 1.4482 - val_cat_cohesion_accuracy: 0.3478 - val_cat_syntax_accuracy: 0.3811 - val_cat_vocabulary_accuracy: 0.4783 - val_cat_phraseology_accuracy: 0.3939 - val_cat_grammar_accuracy: 0.3453 - val_cat_conventions_accuracy: 0.4092
# Epoch 5/5
# 391/391 [==============================] - 394s 1s/step - loss: 8.5811 - cat_cohesion_loss: 1.4837 - cat_syntax_loss: 1.3605 - cat_vocabulary_loss: 1.3421 - cat_phraseology_loss: 1.4601 - cat_grammar_loss: 1.5081 - cat_conventions_loss: 1.4265 - cat_cohesion_accuracy: 0.3878 - cat_syntax_accuracy: 0.4520 - cat_vocabulary_accuracy: 0.4715 - cat_phraseology_accuracy: 0.4172 - cat_grammar_accuracy: 0.4076 - cat_conventions_accuracy: 0.4265 - val_loss: 9.1821 - val_cat_cohesion_loss: 1.5064 - val_cat_syntax_loss: 1.5810 - val_cat_vocabulary_loss: 1.4348 - val_cat_phraseology_loss: 1.6007 - val_cat_grammar_loss: 1.5642 - val_cat_conventions_loss: 1.4950 - val_cat_cohesion_accuracy: 0.3248 - val_cat_syntax_accuracy: 0.3453 - val_cat_vocabulary_accuracy: 0.4246 - val_cat_phraseology_accuracy: 0.3504 - val_cat_grammar_accuracy: 0.3453 - val_cat_conventions_accuracy: 0.3964
#                                       0          1         2         3  \
# loss                          11.265678  10.295145  9.697035  9.160075
# cat_cohesion_loss              1.842095   1.747775  1.659794  1.588050
# cat_syntax_loss                1.780066   1.647821  1.534347  1.466451
# cat_vocabulary_loss            1.715101   1.574792  1.486973  1.412543
# cat_phraseology_loss           2.067770   1.822391  1.703284  1.565565
# cat_grammar_loss               1.938625   1.811216  1.696002  1.604309
# cat_conventions_loss           1.922019   1.691156  1.616638  1.523165
# cat_cohesion_accuracy          0.296995   0.316496  0.330882  0.361573
# cat_syntax_accuracy            0.301471   0.338875  0.376279  0.394501
# cat_vocabulary_accuracy        0.342711   0.394501  0.421355  0.447570
# cat_phraseology_accuracy       0.193095   0.300512  0.333440  0.403133
# cat_grammar_accuracy           0.266624   0.309463  0.338235  0.368286
# cat_conventions_accuracy       0.257992   0.339834  0.350064  0.394182
# val_loss                       9.875533   9.276727  9.311611  8.955193
# val_cat_cohesion_loss          1.649598   1.548587  1.567275  1.531023
# val_cat_syntax_loss            1.608055   1.538398  1.547846  1.519557
# val_cat_vocabulary_loss        1.515093   1.429964  1.452103  1.389344
# val_cat_phraseology_loss       1.759343   1.643102  1.584518  1.517321
# val_cat_grammar_loss           1.689644   1.592854  1.612993  1.549730
# val_cat_conventions_loss       1.653800   1.523823  1.546875  1.448216
# val_cat_cohesion_accuracy      0.322251   0.383632  0.312020  0.347826
# val_cat_syntax_accuracy        0.368286   0.355499  0.381074  0.381074
# val_cat_vocabulary_accuracy    0.483376   0.452685  0.437340  0.478261
# val_cat_phraseology_accuracy   0.286445   0.386189  0.393862  0.393862
# val_cat_grammar_accuracy       0.329923   0.393862  0.383632  0.345269
# val_cat_conventions_accuracy   0.363171   0.404092  0.363171  0.409207
#
#                                      4
# loss                          8.581052
# cat_cohesion_loss             1.483680
# cat_syntax_loss               1.360505
# cat_vocabulary_loss           1.342148
# cat_phraseology_loss          1.460081
# cat_grammar_loss              1.508118
# cat_conventions_loss          1.426525
# cat_cohesion_accuracy         0.387788
# cat_syntax_accuracy           0.452046
# cat_vocabulary_accuracy       0.471547
# cat_phraseology_accuracy      0.417199
# cat_grammar_accuracy          0.407609
# cat_conventions_accuracy      0.426471
# val_loss                      9.182115
# val_cat_cohesion_loss         1.506410
# val_cat_syntax_loss           1.580958
# val_cat_vocabulary_loss       1.434837
# val_cat_phraseology_loss      1.600711
# val_cat_grammar_loss          1.564208
# val_cat_conventions_loss      1.494990
# val_cat_cohesion_accuracy     0.324808
# val_cat_syntax_accuracy       0.345269
# val_cat_vocabulary_accuracy   0.424552
# val_cat_phraseology_accuracy  0.350384
# val_cat_grammar_accuracy      0.345269
# val_cat_conventions_accuracy  0.396419

# %%
score_classification_model_1 = bert_classification_model_1.evaluate([test_encodings.input_ids, 
                                                                     test_encodings.token_type_ids, 
                                                                     test_encodings.attention_mask
                                                                    ], 
                                                                    y_test_map_combined
                                                                   ) 

print('Test loss:', score_classification_model_1[0]) 
print('Test accuracy:', score_classification_model_1[1])
# Out:
# 13/13 [==============================] - 16s 1s/step - loss: 9.3089 - cat_cohesion_loss: 1.6537 - cat_syntax_loss: 1.5352 - cat_vocabulary_loss: 1.4573 - cat_phraseology_loss: 1.5425 - cat_grammar_loss: 1.6286 - cat_conventions_loss: 1.4916 - cat_cohesion_accuracy: 0.3214 - cat_syntax_accuracy: 0.3852 - cat_vocabulary_accuracy: 0.4107 - cat_phraseology_accuracy: 0.3980 - cat_grammar_accuracy: 0.3418 - cat_conventions_accuracy: 0.3903
# Test loss: 9.30888557434082
# Test accuracy: 1.653748631477356

# %%
predictions_classification_model_1 = bert_classification_model_1.predict([test_encodings.input_ids, 
                                                                          test_encodings.token_type_ids, 
                                                                          test_encodings.attention_mask
                                                                          ]
                                                                         )
predictions_classification_model_1 = np.clip(predictions_classification_model_1, 0, 8)
predictions_classification_model_1
# Out:
# 13/13 [==============================] - 19s 1s/step
# array([[[0.00612339, 0.01191559, 0.04582397, ..., 0.07218973,
#          0.0039301 , 0.00494404],
#         [0.00486908, 0.01432502, 0.0940328 , ..., 0.02867579,
#          0.00296796, 0.01154252],
#         [0.00609966, 0.01948502, 0.03505516, ..., 0.06655247,
#          0.00289348, 0.00598541],
#         ...,
#         [0.03147547, 0.03927502, 0.01963925, ..., 0.35135806,
#          0.10099194, 0.00734206],
#         [0.01555957, 0.01868024, 0.03696053, ..., 0.1542113 ,
#          0.0064791 , 0.00269864],
#         [0.00581213, 0.03005216, 0.2078799 , ..., 0.02241697,
#          0.00570535, 0.01284226]],
#
#        [[0.00950059, 0.02229202, 0.02870199, ..., 0.11196648,
#          0.01522578, 0.0227483 ],
#         [0.00347913, 0.01485827, 0.10233175, ..., 0.03732693,
#          0.00829649, 0.01761165],
#         [0.00645266, 0.01394541, 0.02165619, ..., 0.08834506,
#          0.00860958, 0.00926041],
#         ...,
#         [0.02366818, 0.00556825, 0.00580044, ..., 0.39617428,
#          0.06808528, 0.04433971],
#         [0.00535509, 0.01545264, 0.00827911, ..., 0.07570387,
#          0.00774152, 0.01415427],
#         [0.00396882, 0.02227064, 0.22721496, ..., 0.02619685,
#          0.01609946, 0.02248592]],
#
#        [[0.02060053, 0.01723408, 0.01832841, ..., 0.06991659,
#          0.03469998, 0.00592165],
#         [0.01689322, 0.01617133, 0.01016537, ..., 0.02460071,
#          0.01436442, 0.00486287],
#         [0.01589668, 0.02215908, 0.01591713, ..., 0.04256264,
#          0.02365256, 0.00391498],
#         ...,
#         [0.05342317, 0.00724803, 0.03346052, ..., 0.32578197,
#          0.15016373, 0.04152359],
#         [0.01667827, 0.01955404, 0.03416685, ..., 0.20291509,
#          0.05289524, 0.00756427],
#         [0.01736842, 0.0139659 , 0.02644061, ..., 0.02661868,
#          0.01590623, 0.00583972]],
#
#        [[0.03007042, 0.00327808, 0.03648666, ..., 0.07374773,
#          0.01853929, 0.05448378],
#         [0.01457425, 0.00689996, 0.19953543, ..., 0.03180497,
#          0.01767005, 0.02500131],
#         [0.01927132, 0.00412958, 0.03724274, ..., 0.09250099,
#          0.01534108, 0.04178997],
#         ...,
#         [0.02827306, 0.00576019, 0.07137646, ..., 0.47140968,
#          0.09514947, 0.05349877],
#         [0.02259846, 0.00267201, 0.03104836, ..., 0.1245453 ,
#          0.02328823, 0.04784511],
#         [0.00992988, 0.01221081, 0.32589462, ..., 0.02919281,
#          0.01961938, 0.01134061]],
#
#        [[0.01517753, 0.03114605, 0.06891504, ..., 0.0515663 ,
#          0.01084707, 0.02266315],
#         [0.00769918, 0.03471064, 0.35585067, ..., 0.01527538,
#          0.0048327 , 0.00850498],
#         [0.02097654, 0.03205797, 0.07732918, ..., 0.03489603,
#          0.01213056, 0.02148529],
#         ...,
#         [0.02486561, 0.02962457, 0.06403556, ..., 0.31686237,
#          0.14377497, 0.10522453],
#         [0.03148459, 0.02255125, 0.04987775, ..., 0.10048663,
#          0.014576  , 0.02101367],
#         [0.00694545, 0.04324019, 0.4815012 , ..., 0.02741739,
#          0.00926044, 0.01345006]],
#
#        [[0.00519319, 0.01593699, 0.01945441, ..., 0.05725685,
#          0.02119048, 0.00548734],
#         [0.00907828, 0.01519257, 0.15227139, ..., 0.03415924,
#          0.01364891, 0.01870627],
#         [0.00841957, 0.01777041, 0.02213307, ..., 0.04353331,
#          0.02182952, 0.00771328],
#         ...,
#         [0.03775945, 0.00984765, 0.02669111, ..., 0.40552396,
#          0.1747487 , 0.00784955],
#         [0.00855192, 0.01467279, 0.01785173, ..., 0.121291  ,
#          0.03707108, 0.00284736],
#         [0.00881181, 0.01974645, 0.40113264, ..., 0.03305237,
#          0.01313599, 0.01751636]]], dtype=float32)

# %%
plot_loss_accuracy(bert_classification_model_1_history_df, cat_label_cols)

# %% [markdown]
# ## **"bert_classification_model_2" is the baseline classification model with multilabel multi output. We are freezing the pre-trained model.**

# %%
bert_classification_model_2 = create_bert_model(checkpoint = model_checkpoint,
                                                num_classes = 9,   # [1, 1.5, 2, 2.5....4.5, 5]: 9 classes
                                                number_of_hidden_layer = 1,
                                                hidden_layer_node_count = 128,
                                                dropout = 0.3,
                                                learning_rate = 0.00001,
                                                trainable_flag = False,
                                                retrain_layer_count = 999,#All layers trainable
                                                classification_regression_flag = 'C',
                                                max_length = MAX_LENGTH
                                              )

print(bert_classification_model_2.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  attention_mask_layer (InputLay  [(None, 512)]       0           []
#  er)
#
#  input_ids_layer (InputLayer)   [(None, 512)]        0           []
#
#  token_type_ids_layer (InputLay  [(None, 512)]       0           []
#  er)
#
#  bert_model (TFBertModel)       TFBaseModelOutputWi  108310272   ['attention_mask_layer[0][0]',
#                                 thPoolingAndCrossAt               'input_ids_layer[0][0]',
#                                 tentions(last_hidde               'token_type_ids_layer[0][0]']
#                                 n_state=(None, 512,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  tf.__operators__.getitem (Slic  (None, 768)         0           ['bert_model[0][0]']
#  ingOpLambda)
#
#  hidden_layer_1 (Dense)         (None, 128)          98432       ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  dropout_layer (Dropout)        (None, 128)          0           ['hidden_layer_1[0][0]']
#
#  cat_cohesion (Dense)           (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_syntax (Dense)             (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_vocabulary (Dense)         (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_phraseology (Dense)        (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_grammar (Dense)            (None, 9)            1161        ['dropout_layer[0][0]']
#
#  cat_conventions (Dense)        (None, 9)            1161        ['dropout_layer[0][0]']
#
# ==================================================================================================
# Total params: 108,415,670
# Trainable params: 105,398
# Non-trainable params: 108,310,272
# __________________________________________________________________________________________________
# None

# %%
keras.utils.plot_model(bert_classification_model_2, show_shapes=False, show_dtype=False, show_layer_names=True, dpi=90)

# %%
bert_classification_model_2_history = bert_classification_model_2.fit([train_encodings.input_ids, 
                                                                       train_encodings.token_type_ids, 
                                                                       train_encodings.attention_mask
                                                                      ], 
                                                                      y_train_map_combined,   
                                                                      validation_data =([val_encodings.input_ids, 
                                                                                         val_encodings.token_type_ids, 
                                                                                         val_encodings.attention_mask
                                                                                        ], 
                                                                                        y_val_map_combined
                                                                                      ),    
                                                                      batch_size = 8, 
                                                                      epochs = 5
                                                                     )                                                  
bert_classification_model_2_history_df = pd.DataFrame(bert_classification_model_2_history.history)
bert_classification_model_2_history_df.T
# Out:
# Epoch 1/5
# 391/391 [==============================] - 177s 425ms/step - loss: 13.2833 - cat_cohesion_loss: 2.1008 - cat_syntax_loss: 2.2684 - cat_vocabulary_loss: 2.0950 - cat_phraseology_loss: 2.1381 - cat_grammar_loss: 2.3257 - cat_conventions_loss: 2.3554 - cat_cohesion_accuracy: 0.2190 - cat_syntax_accuracy: 0.1285 - cat_vocabulary_accuracy: 0.1320 - cat_phraseology_accuracy: 0.2318 - cat_grammar_accuracy: 0.1212 - cat_conventions_accuracy: 0.1231 - val_loss: 11.8333 - val_cat_cohesion_loss: 1.9125 - val_cat_syntax_loss: 2.0329 - val_cat_vocabulary_loss: 1.8434 - val_cat_phraseology_loss: 1.9244 - val_cat_grammar_loss: 2.0817 - val_cat_conventions_loss: 2.0384 - val_cat_cohesion_accuracy: 0.2685 - val_cat_syntax_accuracy: 0.2481 - val_cat_vocabulary_accuracy: 0.1816 - val_cat_phraseology_accuracy: 0.2660 - val_cat_grammar_accuracy: 0.2506 - val_cat_conventions_accuracy: 0.3069
# Epoch 2/5
# 391/391 [==============================] - 163s 416ms/step - loss: 11.9324 - cat_cohesion_loss: 1.9545 - cat_syntax_loss: 2.0287 - cat_vocabulary_loss: 1.8393 - cat_phraseology_loss: 1.9691 - cat_grammar_loss: 2.0736 - cat_conventions_loss: 2.0673 - cat_cohesion_accuracy: 0.2423 - cat_syntax_accuracy: 0.2244 - cat_vocabulary_accuracy: 0.2414 - cat_phraseology_accuracy: 0.2299 - cat_grammar_accuracy: 0.1915 - cat_conventions_accuracy: 0.2270 - val_loss: 10.9636 - val_cat_cohesion_loss: 1.7953 - val_cat_syntax_loss: 1.8654 - val_cat_vocabulary_loss: 1.6770 - val_cat_phraseology_loss: 1.8246 - val_cat_grammar_loss: 1.9246 - val_cat_conventions_loss: 1.8767 - val_cat_cohesion_accuracy: 0.2737 - val_cat_syntax_accuracy: 0.2992 - val_cat_vocabulary_accuracy: 0.3939 - val_cat_phraseology_accuracy: 0.2583 - val_cat_grammar_accuracy: 0.2583 - val_cat_conventions_accuracy: 0.3018
# Epoch 3/5
# 391/391 [==============================] - 162s 415ms/step - loss: 11.4204 - cat_cohesion_loss: 1.9036 - cat_syntax_loss: 1.9334 - cat_vocabulary_loss: 1.7299 - cat_phraseology_loss: 1.9000 - cat_grammar_loss: 1.9743 - cat_conventions_loss: 1.9792 - cat_cohesion_accuracy: 0.2311 - cat_syntax_accuracy: 0.2522 - cat_vocabulary_accuracy: 0.3095 - cat_phraseology_accuracy: 0.2506 - cat_grammar_accuracy: 0.2120 - cat_conventions_accuracy: 0.2279 - val_loss: 10.5829 - val_cat_cohesion_loss: 1.7421 - val_cat_syntax_loss: 1.7979 - val_cat_vocabulary_loss: 1.6129 - val_cat_phraseology_loss: 1.7690 - val_cat_grammar_loss: 1.8577 - val_cat_conventions_loss: 1.8033 - val_cat_cohesion_accuracy: 0.2711 - val_cat_syntax_accuracy: 0.3197 - val_cat_vocabulary_accuracy: 0.4015 - val_cat_phraseology_accuracy: 0.2788 - val_cat_grammar_accuracy: 0.2583 - val_cat_conventions_accuracy: 0.3043
# Epoch 4/5
# 391/391 [==============================] - 162s 416ms/step - loss: 11.1272 - cat_cohesion_loss: 1.8619 - cat_syntax_loss: 1.8783 - cat_vocabulary_loss: 1.6966 - cat_phraseology_loss: 1.8596 - cat_grammar_loss: 1.9199 - cat_conventions_loss: 1.9109 - cat_cohesion_accuracy: 0.2455 - cat_syntax_accuracy: 0.2621 - cat_vocabulary_accuracy: 0.3296 - cat_phraseology_accuracy: 0.2395 - cat_grammar_accuracy: 0.2273 - cat_conventions_accuracy: 0.2580 - val_loss: 10.3860 - val_cat_cohesion_loss: 1.7154 - val_cat_syntax_loss: 1.7598 - val_cat_vocabulary_loss: 1.5872 - val_cat_phraseology_loss: 1.7373 - val_cat_grammar_loss: 1.8209 - val_cat_conventions_loss: 1.7654 - val_cat_cohesion_accuracy: 0.2711 - val_cat_syntax_accuracy: 0.3350 - val_cat_vocabulary_accuracy: 0.4066 - val_cat_phraseology_accuracy: 0.2864 - val_cat_grammar_accuracy: 0.2609 - val_cat_conventions_accuracy: 0.3043
# Epoch 5/5
# 391/391 [==============================] - 158s 405ms/step - loss: 10.9819 - cat_cohesion_loss: 1.8430 - cat_syntax_loss: 1.8328 - cat_vocabulary_loss: 1.6867 - cat_phraseology_loss: 1.8397 - cat_grammar_loss: 1.8950 - cat_conventions_loss: 1.8847 - cat_cohesion_accuracy: 0.2407 - cat_syntax_accuracy: 0.2714 - cat_vocabulary_accuracy: 0.3338 - cat_phraseology_accuracy: 0.2487 - cat_grammar_accuracy: 0.2401 - cat_conventions_accuracy: 0.2548 - val_loss: 10.2714 - val_cat_cohesion_loss: 1.7035 - val_cat_syntax_loss: 1.7413 - val_cat_vocabulary_loss: 1.5707 - val_cat_phraseology_loss: 1.7182 - val_cat_grammar_loss: 1.7993 - val_cat_conventions_loss: 1.7385 - val_cat_cohesion_accuracy: 0.2788 - val_cat_syntax_accuracy: 0.3376 - val_cat_vocabulary_accuracy: 0.4041 - val_cat_phraseology_accuracy: 0.2916 - val_cat_grammar_accuracy: 0.2711 - val_cat_conventions_accuracy: 0.3018
#                                       0          1          2          3  \
# loss                          13.283331  11.932364  11.420434  11.127206
# cat_cohesion_loss              2.100782   1.954482   1.903616   1.861866
# cat_syntax_loss                2.268395   2.028671   1.933427   1.878341
# cat_vocabulary_loss            2.095018   1.839289   1.729869   1.696568
# cat_phraseology_loss           2.138056   1.969081   1.900032   1.859634
# cat_grammar_loss               2.325665   2.073571   1.974273   1.919874
# cat_conventions_loss           2.355409   2.067265   1.979215   1.910921
# cat_cohesion_accuracy          0.218990   0.242327   0.231138   0.245524
# cat_syntax_accuracy            0.128517   0.224425   0.252238   0.262148
# cat_vocabulary_accuracy        0.132033   0.241368   0.309463   0.329604
# cat_phraseology_accuracy       0.231777   0.229859   0.250639   0.239450
# cat_grammar_accuracy           0.121164   0.191496   0.211957   0.227302
# cat_conventions_accuracy       0.123082   0.226982   0.227941   0.257992
# val_loss                      11.833298  10.963642  10.582874  10.385969
# val_cat_cohesion_loss          1.912464   1.795300   1.742058   1.715357
# val_cat_syntax_loss            2.032884   1.865440   1.797909   1.759785
# val_cat_vocabulary_loss        1.843441   1.676964   1.612887   1.587198
# val_cat_phraseology_loss       1.924364   1.824646   1.768996   1.737334
# val_cat_grammar_loss           2.081701   1.924642   1.857730   1.820920
# val_cat_conventions_loss       2.038445   1.876653   1.803294   1.765375
# val_cat_cohesion_accuracy      0.268542   0.273657   0.271100   0.271100
# val_cat_syntax_accuracy        0.248082   0.299233   0.319693   0.335038
# val_cat_vocabulary_accuracy    0.181586   0.393862   0.401535   0.406650
# val_cat_phraseology_accuracy   0.265985   0.258312   0.278772   0.286445
# val_cat_grammar_accuracy       0.250639   0.258312   0.258312   0.260870
# val_cat_conventions_accuracy   0.306905   0.301790   0.304348   0.304348
#
#                                       4
# loss                          10.981906
# cat_cohesion_loss              1.842968
# cat_syntax_loss                1.832836
# cat_vocabulary_loss            1.686664
# cat_phraseology_loss           1.839749
# cat_grammar_loss               1.894978
# cat_conventions_loss           1.884710
# cat_cohesion_accuracy          0.240729
# cat_syntax_accuracy            0.271419
# cat_vocabulary_accuracy        0.333760
# cat_phraseology_accuracy       0.248721
# cat_grammar_accuracy           0.240090
# cat_conventions_accuracy       0.254795
# val_loss                      10.271427
# val_cat_cohesion_loss          1.703483
# val_cat_syntax_loss            1.741294
# val_cat_vocabulary_loss        1.570682
# val_cat_phraseology_loss       1.718172
# val_cat_grammar_loss           1.799338
# val_cat_conventions_loss       1.738456
# val_cat_cohesion_accuracy      0.278772
# val_cat_syntax_accuracy        0.337596
# val_cat_vocabulary_accuracy    0.404092
# val_cat_phraseology_accuracy   0.291560
# val_cat_grammar_accuracy       0.271100
# val_cat_conventions_accuracy   0.301790

# %%
score_classification_model_2 = bert_classification_model_2.evaluate([test_encodings.input_ids, 
                                                                     test_encodings.token_type_ids, 
                                                                     test_encodings.attention_mask
                                                                    ], 
                                                                    y_test_map_combined
                                                                   ) 

print('Test loss:', score_classification_model_2[0]) 
print('Test accuracy:', score_classification_model_2[1])
# Out:
# 13/13 [==============================] - 16s 1s/step - loss: 10.4182 - cat_cohesion_loss: 1.7849 - cat_syntax_loss: 1.7319 - cat_vocabulary_loss: 1.5913 - cat_phraseology_loss: 1.7308 - cat_grammar_loss: 1.8040 - cat_conventions_loss: 1.7752 - cat_cohesion_accuracy: 0.2602 - cat_syntax_accuracy: 0.3112 - cat_vocabulary_accuracy: 0.3750 - cat_phraseology_accuracy: 0.3163 - cat_grammar_accuracy: 0.2372 - cat_conventions_accuracy: 0.3240
# Test loss: 10.41817855834961
# Test accuracy: 1.7849273681640625

# %%
predictions_classification_model_2 = bert_classification_model_2.predict([test_encodings.input_ids, 
                                                                          test_encodings.token_type_ids, 
                                                                          test_encodings.attention_mask
                                                                          ]
                                                                         )
predictions_classification_model_2 = np.clip(predictions_classification_model_2, 0, 8)
predictions_classification_model_2
# Out:
# 13/13 [==============================] - 20s 1s/step
# array([[[0.02829033, 0.02729909, 0.05684338, ..., 0.15136537,
#          0.03481774, 0.01477345],
#         [0.02514205, 0.0311156 , 0.06532034, ..., 0.13649717,
#          0.04696719, 0.01598805],
#         [0.02275569, 0.02804461, 0.06190408, ..., 0.15858406,
#          0.0497903 , 0.01173925],
#         ...,
#         [0.03030506, 0.03161221, 0.06195866, ..., 0.19062637,
#          0.02533299, 0.01251287],
#         [0.02615745, 0.03164432, 0.06916119, ..., 0.14684315,
#          0.04062039, 0.01548745],
#         [0.01858736, 0.02323114, 0.05685842, ..., 0.16611199,
#          0.03131301, 0.01307412]],
#
#        [[0.05078164, 0.03657657, 0.11546392, ..., 0.08714123,
#          0.04834298, 0.01388418],
#         [0.05140188, 0.02906919, 0.1141706 , ..., 0.09423497,
#          0.04346139, 0.01637332],
#         [0.04505052, 0.03320167, 0.12752192, ..., 0.07963771,
#          0.03810706, 0.01411896],
#         ...,
#         [0.05849234, 0.02971294, 0.10417305, ..., 0.10833978,
#          0.04284678, 0.01640491],
#         [0.05549867, 0.03424154, 0.12248417, ..., 0.10258101,
#          0.0364734 , 0.01635803],
#         [0.05886575, 0.02870458, 0.13811155, ..., 0.08310625,
#          0.03706511, 0.00953663]],
#
#        [[0.00595785, 0.02857417, 0.04901731, ..., 0.13663997,
#          0.01857655, 0.01893941],
#         [0.00808062, 0.02939365, 0.05712579, ..., 0.16489549,
#          0.01880989, 0.01795198],
#         [0.00655282, 0.02516391, 0.05086977, ..., 0.12238669,
#          0.01814387, 0.01659034],
#         ...,
#         [0.00670374, 0.02957567, 0.07370729, ..., 0.14875846,
#          0.02222333, 0.01936678],
#         [0.00678319, 0.03554737, 0.07178412, ..., 0.10139933,
#          0.02082915, 0.01364133],
#         [0.00473974, 0.02427989, 0.07093235, ..., 0.10512621,
#          0.01887229, 0.01303883]],
#
#        [[0.02470478, 0.02009426, 0.07619059, ..., 0.14353226,
#          0.05423242, 0.03186182],
#         [0.02207681, 0.01712354, 0.07958532, ..., 0.1135927 ,
#          0.06628314, 0.02474227],
#         [0.02077022, 0.01732374, 0.06501618, ..., 0.0995741 ,
#          0.04906185, 0.02458815],
#         ...,
#         [0.01847304, 0.01640987, 0.07364727, ..., 0.15910897,
#          0.05193196, 0.03465458],
#         [0.0325172 , 0.02885809, 0.06031966, ..., 0.16017322,
#          0.05914809, 0.02513709],
#         [0.02682783, 0.01670895, 0.04951841, ..., 0.12397989,
#          0.04286753, 0.02362881]],
#
#        [[0.0253135 , 0.02154492, 0.12587088, ..., 0.07109949,
#          0.07104207, 0.03119353],
#         [0.02703964, 0.02975314, 0.12726776, ..., 0.08875933,
#          0.08319811, 0.02975316],
#         [0.02456371, 0.02109092, 0.11984538, ..., 0.07522639,
#          0.07774337, 0.02489367],
#         ...,
#         [0.02292452, 0.02245875, 0.10925352, ..., 0.07050241,
#          0.10629602, 0.02486998],
#         [0.0252569 , 0.02440499, 0.1463191 , ..., 0.10127866,
#          0.07172327, 0.02406421],
#         [0.02151725, 0.01668544, 0.13428895, ..., 0.07446772,
#          0.05982966, 0.02427743]],
#
#        [[0.03647787, 0.03394721, 0.12229693, ..., 0.10965349,
#          0.06234083, 0.02403656],
#         [0.04119746, 0.03540491, 0.09776796, ..., 0.11597372,
#          0.05486515, 0.02600555],
#         [0.04786005, 0.03518051, 0.09294739, ..., 0.12323833,
#          0.061866  , 0.02635884],
#         ...,
#         [0.02880276, 0.03576476, 0.0769984 , ..., 0.13044094,
#          0.04025686, 0.02560395],
#         [0.03747171, 0.0392461 , 0.10836866, ..., 0.10422653,
#          0.05350018, 0.02613232],
#         [0.03094453, 0.02937545, 0.11595765, ..., 0.10260294,
#          0.05222098, 0.02555561]]], dtype=float32)

# %%
plot_loss_accuracy(bert_classification_model_2_history_df, cat_label_cols)

# %% [markdown]
# ## **"bert_classification_model_3" is the baseline classification model with multilabel multi output (1..5). We are un-freezing the pre-trained model and running with scaled output levels.**

# %%
bert_classification_model_3 = create_bert_model(checkpoint = model_checkpoint,
                                                num_classes = 5,   # [1, 1.5, 2, 2.5....4.5, 5]: 9 classes
                                                number_of_hidden_layer = 1,
                                                hidden_layer_node_count = 128,
                                                dropout = 0.3,
                                                learning_rate = 0.00001,
                                                trainable_flag = True,
                                                retrain_layer_count = 999,#All layers trainable
                                                classification_regression_flag = 'C',
                                                max_length = MAX_LENGTH
                                              )

print(bert_classification_model_3.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  attention_mask_layer (InputLay  [(None, 512)]       0           []
#  er)
#
#  input_ids_layer (InputLayer)   [(None, 512)]        0           []
#
#  token_type_ids_layer (InputLay  [(None, 512)]       0           []
#  er)
#
#  bert_model (TFBertModel)       TFBaseModelOutputWi  108310272   ['attention_mask_layer[0][0]',
#                                 thPoolingAndCrossAt               'input_ids_layer[0][0]',
#                                 tentions(last_hidde               'token_type_ids_layer[0][0]']
#                                 n_state=(None, 512,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  tf.__operators__.getitem (Slic  (None, 768)         0           ['bert_model[0][0]']
#  ingOpLambda)
#
#  hidden_layer_1 (Dense)         (None, 128)          98432       ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  dropout_layer (Dropout)        (None, 128)          0           ['hidden_layer_1[0][0]']
#
#  cat_cohesion (Dense)           (None, 5)            645         ['dropout_layer[0][0]']
#
#  cat_syntax (Dense)             (None, 5)            645         ['dropout_layer[0][0]']
#
#  cat_vocabulary (Dense)         (None, 5)            645         ['dropout_layer[0][0]']
#
#  cat_phraseology (Dense)        (None, 5)            645         ['dropout_layer[0][0]']
#
#  cat_grammar (Dense)            (None, 5)            645         ['dropout_layer[0][0]']
#
#  cat_conventions (Dense)        (None, 5)            645         ['dropout_layer[0][0]']
#
# ==================================================================================================
# Total params: 108,412,574
# Trainable params: 108,412,574
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
keras.utils.plot_model(bert_classification_model_3, show_shapes=False, show_dtype=False, show_layer_names=True, dpi=90)

# %%
bert_classification_model_3_history = bert_classification_model_3.fit([train_encodings.input_ids, 
                                                                       train_encodings.token_type_ids, 
                                                                       train_encodings.attention_mask
                                                                      ], 
                                                                      y_train_scaled_combined,   
                                                                      validation_data =([val_encodings.input_ids, 
                                                                                         val_encodings.token_type_ids, 
                                                                                         val_encodings.attention_mask
                                                                                        ], 
                                                                                        y_val_scaled_combined
                                                                                      ),    
                                                                      batch_size = 8, 
                                                                      epochs = 5
                                                                     )                                                  
bert_classification_model_3_history_df = pd.DataFrame(bert_classification_model_3_history.history)
bert_classification_model_3_history_df.T
# Out:
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 391/391 [==============================] - 390s 893ms/step - loss: nan - cat_cohesion_loss: nan - cat_syntax_loss: nan - cat_vocabulary_loss: nan - cat_phraseology_loss: nan - cat_grammar_loss: nan - cat_conventions_loss: nan - cat_cohesion_accuracy: 0.0042 - cat_syntax_accuracy: 0.0042 - cat_vocabulary_accuracy: 0.0051 - cat_phraseology_accuracy: 0.0061 - cat_grammar_accuracy: 0.0016 - cat_conventions_accuracy: 0.0045 - val_loss: nan - val_cat_cohesion_loss: nan - val_cat_syntax_loss: nan - val_cat_vocabulary_loss: nan - val_cat_phraseology_loss: nan - val_cat_grammar_loss: nan - val_cat_conventions_loss: nan - val_cat_cohesion_accuracy: 0.0000e+00 - val_cat_syntax_accuracy: 0.0000e+00 - val_cat_vocabulary_accuracy: 0.0000e+00 - val_cat_phraseology_accuracy: 0.0000e+00 - val_cat_grammar_accuracy: 0.0000e+00 - val_cat_conventions_accuracy: 0.0000e+00
# Epoch 2/5
# 391/391 [==============================] - 345s 883ms/step - loss: nan - cat_cohesion_loss: nan - cat_syntax_loss: nan - cat_vocabulary_loss: nan - cat_phraseology_loss: nan - cat_grammar_loss: nan - cat_conventions_loss: nan - cat_cohesion_accuracy: 0.0000e+00 - cat_syntax_accuracy: 0.0000e+00 - cat_vocabulary_accuracy: 0.0000e+00 - cat_phraseology_accuracy: 0.0000e+00 - cat_grammar_accuracy: 0.0000e+00 - cat_conventions_accuracy: 0.0000e+00 - val_loss: nan - val_cat_cohesion_loss: nan - val_cat_syntax_loss: nan - val_cat_vocabulary_loss: nan - val_cat_phraseology_loss: nan - val_cat_grammar_loss: nan - val_cat_conventions_loss: nan - val_cat_cohesion_accuracy: 0.0000e+00 - val_cat_syntax_accuracy: 0.0000e+00 - val_cat_vocabulary_accuracy: 0.0000e+00 - val_cat_phraseology_accuracy: 0.0000e+00 - val_cat_grammar_accuracy: 0.0000e+00 - val_cat_conventions_accuracy: 0.0000e+00
# Epoch 3/5
# 391/391 [==============================] - 345s 882ms/step - loss: nan - cat_cohesion_loss: nan - cat_syntax_loss: nan - cat_vocabulary_loss: nan - cat_phraseology_loss: nan - cat_grammar_loss: nan - cat_conventions_loss: nan - cat_cohesion_accuracy: 0.0000e+00 - cat_syntax_accuracy: 0.0000e+00 - cat_vocabulary_accuracy: 0.0000e+00 - cat_phraseology_accuracy: 0.0000e+00 - cat_grammar_accuracy: 0.0000e+00 - cat_conventions_accuracy: 0.0000e+00 - val_loss: nan - val_cat_cohesion_loss: nan - val_cat_syntax_loss: nan - val_cat_vocabulary_loss: nan - val_cat_phraseology_loss: nan - val_cat_grammar_loss: nan - val_cat_conventions_loss: nan - val_cat_cohesion_accuracy: 0.0000e+00 - val_cat_syntax_accuracy: 0.0000e+00 - val_cat_vocabulary_accuracy: 0.0000e+00 - val_cat_phraseology_accuracy: 0.0000e+00 - val_cat_grammar_accuracy: 0.0000e+00 - val_cat_conventions_accuracy: 0.0000e+00
# Epoch 4/5
# 391/391 [==============================] - 345s 882ms/step - loss: nan - cat_cohesion_loss: nan - cat_syntax_loss: nan - cat_vocabulary_loss: nan - cat_phraseology_loss: nan - cat_grammar_loss: nan - cat_conventions_loss: nan - cat_cohesion_accuracy: 0.0000e+00 - cat_syntax_accuracy: 0.0000e+00 - cat_vocabulary_accuracy: 0.0000e+00 - cat_phraseology_accuracy: 0.0000e+00 - cat_grammar_accuracy: 0.0000e+00 - cat_conventions_accuracy: 0.0000e+00 - val_loss: nan - val_cat_cohesion_loss: nan - val_cat_syntax_loss: nan - val_cat_vocabulary_loss: nan - val_cat_phraseology_loss: nan - val_cat_grammar_loss: nan - val_cat_conventions_loss: nan - val_cat_cohesion_accuracy: 0.0000e+00 - val_cat_syntax_accuracy: 0.0000e+00 - val_cat_vocabulary_accuracy: 0.0000e+00 - val_cat_phraseology_accuracy: 0.0000e+00 - val_cat_grammar_accuracy: 0.0000e+00 - val_cat_conventions_accuracy: 0.0000e+00
# Epoch 5/5
# 391/391 [==============================] - 345s 882ms/step - loss: nan - cat_cohesion_loss: nan - cat_syntax_loss: nan - cat_vocabulary_loss: nan - cat_phraseology_loss: nan - cat_grammar_loss: nan - cat_conventions_loss: nan - cat_cohesion_accuracy: 0.0000e+00 - cat_syntax_accuracy: 0.0000e+00 - cat_vocabulary_accuracy: 0.0000e+00 - cat_phraseology_accuracy: 0.0000e+00 - cat_grammar_accuracy: 0.0000e+00 - cat_conventions_accuracy: 0.0000e+00 - val_loss: nan - val_cat_cohesion_loss: nan - val_cat_syntax_loss: nan - val_cat_vocabulary_loss: nan - val_cat_phraseology_loss: nan - val_cat_grammar_loss: nan - val_cat_conventions_loss: nan - val_cat_cohesion_accuracy: 0.0000e+00 - val_cat_syntax_accuracy: 0.0000e+00 - val_cat_vocabulary_accuracy: 0.0000e+00 - val_cat_phraseology_accuracy: 0.0000e+00 - val_cat_grammar_accuracy: 0.0000e+00 - val_cat_conventions_accuracy: 0.0000e+00
#                                      0    1    2    3    4
# loss                               NaN  NaN  NaN  NaN  NaN
# cat_cohesion_loss                  NaN  NaN  NaN  NaN  NaN
# cat_syntax_loss                    NaN  NaN  NaN  NaN  NaN
# cat_vocabulary_loss                NaN  NaN  NaN  NaN  NaN
# cat_phraseology_loss               NaN  NaN  NaN  NaN  NaN
# cat_grammar_loss                   NaN  NaN  NaN  NaN  NaN
# cat_conventions_loss               NaN  NaN  NaN  NaN  NaN
# cat_cohesion_accuracy         0.004156  0.0  0.0  0.0  0.0
# cat_syntax_accuracy           0.004156  0.0  0.0  0.0  0.0
# cat_vocabulary_accuracy       0.005115  0.0  0.0  0.0  0.0
# cat_phraseology_accuracy      0.006074  0.0  0.0  0.0  0.0
# cat_grammar_accuracy          0.001598  0.0  0.0  0.0  0.0
# cat_conventions_accuracy      0.004476  0.0  0.0  0.0  0.0
# val_loss                           NaN  NaN  NaN  NaN  NaN
# val_cat_cohesion_loss              NaN  NaN  NaN  NaN  NaN
# val_cat_syntax_loss                NaN  NaN  NaN  NaN  NaN
# val_cat_vocabulary_loss            NaN  NaN  NaN  NaN  NaN
# val_cat_phraseology_loss           NaN  NaN  NaN  NaN  NaN
# val_cat_grammar_loss               NaN  NaN  NaN  NaN  NaN
# val_cat_conventions_loss           NaN  NaN  NaN  NaN  NaN
# val_cat_cohesion_accuracy     0.000000  0.0  0.0  0.0  0.0
# val_cat_syntax_accuracy       0.000000  0.0  0.0  0.0  0.0
# val_cat_vocabulary_accuracy   0.000000  0.0  0.0  0.0  0.0
# val_cat_phraseology_accuracy  0.000000  0.0  0.0  0.0  0.0
# val_cat_grammar_accuracy      0.000000  0.0  0.0  0.0  0.0
# val_cat_conventions_accuracy  0.000000  0.0  0.0  0.0  0.0

# %%
score_classification_model_3 = bert_classification_model_3.evaluate([test_encodings.input_ids, 
                                                                     test_encodings.token_type_ids, 
                                                                     test_encodings.attention_mask
                                                                    ], 
                                                                    y_test_scaled_combined
                                                                   ) 

print('Test loss:', score_classification_model_3[0]) 
print('Test accuracy:', score_classification_model_3[1])
# Out:
# 13/13 [==============================] - 14s 1s/step - loss: nan - cat_cohesion_loss: nan - cat_syntax_loss: nan - cat_vocabulary_loss: nan - cat_phraseology_loss: nan - cat_grammar_loss: nan - cat_conventions_loss: nan - cat_cohesion_accuracy: 0.0000e+00 - cat_syntax_accuracy: 0.0000e+00 - cat_vocabulary_accuracy: 0.0000e+00 - cat_phraseology_accuracy: 0.0000e+00 - cat_grammar_accuracy: 0.0000e+00 - cat_conventions_accuracy: 0.0000e+00
# Test loss: nan
# Test accuracy: nan

# %%
predictions_classification_model_3 = bert_classification_model_3.predict([test_encodings.input_ids, 
                                                                          test_encodings.token_type_ids, 
                                                                          test_encodings.attention_mask
                                                                          ]
                                                                         )
predictions_classification_model_3 = np.clip(predictions_classification_model_3, 1, 5)
predictions_classification_model_3
# Out:
# 13/13 [==============================] - 17s 1s/step
# array([[[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
#        [[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
#        [[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
#        [[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
#        [[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]],
#
#        [[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         ...,
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]]], dtype=float32)

# %%
plot_loss_accuracy(bert_classification_model_3_history_df, cat_label_cols)

# %% [markdown]
# ## **"bert_classification_model_4" is the baseline regression model.**

# %%
set_config_param()
bert_model = TFBertModel.from_pretrained(model_checkpoint, name = 'bert_model')    
trainable_flag = True
retrain_layer_count = 999
bert_model.trainable = True  
input_ids = tf.keras.layers.Input(shape=(MAX_LENGTH,), dtype=tf.int64, name='input_ids_layer')
token_type_ids = tf.keras.layers.Input(shape=(MAX_LENGTH,), dtype=tf.int64, name='token_type_ids_layer')
attention_mask = tf.keras.layers.Input(shape=(MAX_LENGTH,), dtype=tf.int64, name='attention_mask_layer')

bert_inputs = {'input_ids': input_ids,
               'token_type_ids': token_type_ids,
               'attention_mask': attention_mask
              }
                   
# Bert output: being used as an input feature in the classification model below
bert_out = bert_model(bert_inputs)        # full features as an input to the following classification model
# pooler_output = bert_out[1]             # one vector for each
cls_token = bert_out[0][:, 0, :]          # give us a raw CLS tokens

layer_list = []
number_of_hidden_layer = 1
hidden_layer_node_count = 64
dropout = .3
classification_regression_flag = 'C'
num_classes = 9
learning_rate = 0.001

for hidden_layer_number in range(number_of_hidden_layer):
    if hidden_layer_number == 0:
        hidden_layer = tf.keras.layers.Dense(units = hidden_layer_node_count
                                    , activation = 'relu'
                                    , name = 'hidden_layer_' + str(hidden_layer_number + 1)
                                     )(cls_token)
    else:
        hidden_layer = tf.keras.layers.Dense(units = hidden_layer_node_count
                                    , activation = 'relu'
                                    , name = 'hidden_layer_' + str(hidden_layer_number + 1)
                                     )(layer_list[-1])
    layer_list.append(hidden_layer)
    dropout_layer = tf.keras.layers.Dropout(dropout, name = 'dropout_layer_' + str(hidden_layer_number + 1))(hidden_layer) 
    layer_list.append(dropout_layer)

output = tf.keras.layers.Dense(6,)(layer_list[-1])
regression_model = tf.keras.Model(inputs = [input_ids, 
                                                    token_type_ids,
                                                    attention_mask
                                                  ], 
                                          outputs = output
                                        )

regression_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate),
                                 loss=MCRMSE
                  , metrics=MCRMSE
                                ) 
print(regression_model.summary())


keras.utils.plot_model(regression_model, show_shapes=False, show_dtype=False, show_layer_names=True, dpi=90)

regression_model_history = regression_model.fit([train_encodings.input_ids, 
                                                                       train_encodings.token_type_ids, 
                                                                       train_encodings.attention_mask
                                                                      ], 
                                                                      y_train,   
                                                                      validation_data =([val_encodings.input_ids, 
                                                                                         val_encodings.token_type_ids, 
                                                                                         val_encodings.attention_mask
                                                                                        ], 
                                                                                        y_val
                                                                                      ),    
                                                                      batch_size = 8, 
                                                                      epochs = 1
                                                                     )                                                  
regression_model_df = pd.DataFrame(regression_model_history.history)
regression_model_df.T
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  attention_mask_layer (InputLay  [(None, 512)]       0           []
#  er)
#
#  input_ids_layer (InputLayer)   [(None, 512)]        0           []
#
#  token_type_ids_layer (InputLay  [(None, 512)]       0           []
#  er)
#
#  bert_model (TFBertModel)       TFBaseModelOutputWi  108310272   ['attention_mask_layer[0][0]',
#                                 thPoolingAndCrossAt               'input_ids_layer[0][0]',
#                                 tentions(last_hidde               'token_type_ids_layer[0][0]']
#                                 n_state=(None, 512,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  tf.__operators__.getitem (Slic  (None, 768)         0           ['bert_model[0][0]']
#  ingOpLambda)
#
#  hidden_layer_1 (Dense)         (None, 64)           49216       ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  dropout_layer_1 (Dropout)      (None, 64)           0           ['hidden_layer_1[0][0]']
#
#  dense (Dense)                  (None, 6)            390         ['dropout_layer_1[0][0]']
#
# ==================================================================================================
# Total params: 108,359,878
# Trainable params: 108,359,878
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bert_model/bert/pooler/dense/kernel:0', 'bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 391/391 [==============================] - 436s 1s/step - loss: 1.0988 - MCRMSE: 1.0988 - val_loss: 0.6632 - val_MCRMSE: 0.6629
#                    0
# loss        1.098797
# MCRMSE      1.098797
# val_loss    0.663187
# val_MCRMSE  0.662889

# %%
keras.utils.plot_model(regression_model, show_shapes=False, show_dtype=False, show_layer_names=True, dpi=90)

# %%
score_regression_model = regression_model.evaluate([test_encodings.input_ids, 
                                                                     test_encodings.token_type_ids, 
                                                                     test_encodings.attention_mask
                                                                    ], 
                                                                    y_test
                                                                   ) 

print(score_regression_model)
# Out:
# 13/13 [==============================] - 16s 1s/step - loss: 0.6988 - MCRMSE: 0.7014
# [0.6988093852996826, 0.7013997435569763]

# %%
predictions_regression_model = regression_model.predict([test_encodings.input_ids, 
                                                                          test_encodings.token_type_ids, 
                                                                          test_encodings.attention_mask
                                                                          ]
                                                                         )
print(predictions_regression_model)
# Out:
# 13/13 [==============================] - 19s 1s/step
# [[3.567556  3.3422947 3.6086924 3.53387   3.3260026 3.4206848]
#  [3.567556  3.3422947 3.6086924 3.5338695 3.3260026 3.4206848]
#  [3.567556  3.3422945 3.608692  3.5338695 3.3260021 3.4206846]
#  ...
#  [3.567556  3.342295  3.608693  3.53387   3.3260024 3.4206848]
#  [3.567556  3.342295  3.6086924 3.5338695 3.3260024 3.4206846]
#  [3.5675554 3.3422945 3.6086924 3.5338695 3.3260021 3.4206846]]

# %%
df_test[label_cols]
# Out:
#       cohesion  syntax  vocabulary  phraseology  grammar  conventions
# 3317       3.5     2.5         3.5          3.5      2.5          3.0
# 3172       3.0     3.0         3.0          3.5      2.5          3.0
# 2999       2.5     2.0         2.5          2.0      2.0          3.0
# 2824       3.5     3.0         3.0          2.5      2.5          3.5
# 310        2.5     2.5         2.5          2.0      2.5          2.0
# ...        ...     ...         ...          ...      ...          ...
# 70         2.5     3.0         3.0          3.0      2.5          2.0
# 1767       3.5     3.0         3.5          3.0      3.5          4.0
# 2424       3.0     3.5         3.5          4.0      4.0          4.0
# 3204       3.0     3.0         3.0          3.0      3.0          2.5
# 651        2.5     2.0         2.0          2.0      2.0          2.0
#
# [392 rows x 6 columns]

# %%
regression_model_df
# Out:
#        loss    MCRMSE  val_loss  val_MCRMSE
# 0  1.098797  1.098797  0.663187    0.662889

# %%
x_arr = np.arange(len(regression_model_df['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, regression_model_df['loss'], '-o', label='Train loss')
ax.plot(x_arr, regression_model_df['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Loss', size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, regression_model_df['MCRMSE'], '-o', label='Train MCRMSE')
ax.plot(x_arr, regression_model_df['val_MCRMSE'], '--<', label='Validation MCRMSE')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Accuracy', size=15)
ax.set_ylim(0,1)
plt.show()
